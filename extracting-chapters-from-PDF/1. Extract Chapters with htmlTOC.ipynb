# %% [markdown]
# # About the code

# %% [markdown]
# This piece of code is divided into 2 parts <br>
# ---> 1. Make Chunks based on the Postal Codes and Table of contents extracted from the HTML: Here we are preparing a dataframe of all the file names that we read and try to divinde them into chunks based on the postal codes and the presence of outlines. <br>
# ---> ---> 1 a.

# %%
import PyPDF2 as p2
from pdfminer.pdfparser import PDFParser
from pdfminer.pdfdocument import PDFDocument
import pandas as pd
import os
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

import json
import numpy as np
import re

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
#define the paths of the PDF scrapped 

path = 'F:/Environmental Baseline Data/Version 3/Data/PDF'
pdfs = os.listdir(path)
pdf_paths = [str(path) + '/' + str(x) for x in pdfs]
len(pdf_paths)
# Out:
# 1329

# %% [markdown]
# # 1. Make Chunks based on the Postal Codes and Outlines

# %% [markdown]
# This part of the code will generate a csv file with all the PDF nammes with the fillowing details: <br> - 'file_nos': just a number to indicate the file
# <br> - 'file_names': the name of the file (Postal Code.pdf)
# <br> - 'file_paths' : the path of the pdf file
# <br> - 'int_postals' : the integer value of the postal code
# <br> - 'chunk_nos': chunk_no based on the consectutive Postal Code

# %% [markdown]
# ### 1 a. Postal to Int Functions

# %%
def postal_to_int(Postal):
    multiplier = 1
    odd = 1
    Postal_Int_Word = 0
    Error_Message = "Invalid Postal Code"
    
    # Reversing the string 
    Postal = Postal[::-1] 
    
    # Chcek for the length of the Postal Code
    if not(len(Postal)==6):
        return(Error_Message)
    
    for letter in list(str.strip(Postal)):
        if odd%2 == 1:
            # Check if it is an interger or not   
            # If this is not an integer then exit
            if not (str.isnumeric(letter)):
                return(Error_Message)
            
            Postal_Int_Letter = multiplier * int(letter)
            Postal_Int_Word = Postal_Int_Word + Postal_Int_Letter
            
            odd = odd + 1
            multiplier = multiplier * 10
            # print(letter, Postal_Int_Letter)
            # print(Postal_Int_Word)
        else:
            # Check if it is a character or not
            # If this is not a character then exit
            if not (str.isalpha(letter)):
                return(Error_Message)
            
            # ord('A') = 65
            Postal_Int_Letter = multiplier * (ord(letter) - 65)
            Postal_Int_Word = Postal_Int_Word + Postal_Int_Letter
            
            odd = odd + 1
            multiplier = multiplier * 26
            # print(letter, Postal_Int_Letter)
            # print(Postal_Int_Word)
            
    return Postal_Int_Word

# %%
# never used integer to Postal but I guess it would be useful 
# Also useful in validating if Postal to Int Function works 

def int_to_postal(Postal_Int_Word):
    Postal_Int_Word_Rem = Postal_Int_Word
    Postal = ""
    odd = 0
    Error_Message = "Invalid Postal Code"
    
    # Reversing the string 
    Postal = Postal[::-1] 
 
    while odd < 6:
        if odd%2 == 0:
            Postal_Int_Letter = Postal_Int_Word_Rem % 10
            Postal = Postal + str(Postal_Int_Letter)
            Postal_Int_Word_Rem = int(Postal_Int_Word_Rem/10)
            odd = odd + 1

        else:
            Postal_Int_Letter = (Postal_Int_Word_Rem % 26) +65
            Postal = Postal + chr(Postal_Int_Letter)
            Postal_Int_Word_Rem = int(Postal_Int_Word_Rem/26)
            odd = odd + 1
            
    # Accounts for 7 digit Postal Codes
    if Postal_Int_Word_Rem > 0:
        return(Error_Message)
        
    return Postal[::-1]

# %%
file_nos = []
file_names = []
file_paths = []
int_postals = []
file_no = 1

for pdf_path in pdf_paths:
    # additional check to get rid of the string "Thumb"
    if 'Thum' in pdf_path:
        continue
    
    file_nos.append(file_no)
    file_name = str(pdf_path.split('/')[-1])
    file_names.append(file_name)
    file_paths.append(pdf_path)
    
    postal = file_name[:-4]
    int_postal = postal_to_int(postal)
    int_postals.append(int_postal)
    
len(file_nos)
len(file_names)
len(file_paths)
len(int_postals)
# Out:
# 1328
# 1328
# 1328
# 1328

# %% [markdown]
# ### 1 c. Check if TOC is present

# %%
# Getting the path of the TOC present
path_Texts = []

for path_pdf in pdf_paths:
    if 'Thumb' in path_pdf:
        continue
    path_Text = path_pdf.replace(" .pdf", "")
    if ".pdf" in path_Text:
        path_Text = path_pdf.replace(".pdf", "")
    #print(path_Text)
    path_Text = path_Text.replace("/PDF", "/HTML Images and Tables")
    path_Text = path_Text + "/table-of-contents.txt"
    path_Texts.append(path_Text)
    #print(path_Text)
    
len(path_Texts)
path_Texts[4]
# Out:
# 1328
# 'F:/Environmental Baseline Data/Version 3/Data/HTML Images and Tables/A0U3G1/table-of-contents.txt'

# %%
# Here we are not saving or extracting the TOCs yet
# Here we are only checking if the extraction of the TOC is possible or not 
TOC_present = []

txt_path = "F:/Environmental Baseline Data/Version 3/Data/Text/"
TOC_present = []
txt_file_needed = []
no_HTML = 0

for path_Text in path_Texts:
    try:
        file_handle = open(path_Text,"r", encoding="utf8")
        if file_handle.mode == 'r':
            contents = file_handle.read()
            contents = contents.upper()
            if 'TABLE OF CONTENTS' in contents:
                TOC_present.append(1)
            else:
                TOC_present.append(0)
                
    except:
        TOC_present.append('0')
        no_HTML = no_HTML+1
        
len(file_nos)
len(file_names)
len(file_paths)
len(int_postals)
len(TOC_present)


print("HTML File does not exist for {} files".format(no_HTML))
# Out:
# 1328
# 1328
# 1328
# 1328
# 1328
# HTML File does not exist for 189 files

# %%
df_outlines = pd.DataFrame({'file_nos': file_nos, 
                            'file_names': file_names, 
                            'file_paths' : file_paths, 
                            'int_postals': int_postals, 
                            #'outline_present': outline_present,
                            'TOC_present': TOC_present})
df_outlines.head(5)
# Out:
#    file_nos  file_names                                         file_paths  \
# 0         1  A0H8C0.pdf  F:/Environmental Baseline Data/Version 3/Data/...
# 1         1  A0H8C1.pdf  F:/Environmental Baseline Data/Version 3/Data/...
# 2         1  A0H8C2.pdf  F:/Environmental Baseline Data/Version 3/Data/...
# 3         1  A0H8C3.pdf  F:/Environmental Baseline Data/Version 3/Data/...
# 4         1  A0U3G1.pdf  F:/Environmental Baseline Data/Version 3/Data/...
#
#    int_postals TOC_present
# 0        20300           1
# 1        20301           0
# 2        20302           0
# 3        20303           0
# 4        52841           1

# %% [markdown]
# ### 1 d. Make Chunks

# %% [markdown]
# Defination of a Chunk: <br>
#     1 Each chunk of the pdf should have consecutive PDF files <br>
#     2 Each chunk of the files can have only one TOC present  <br>
#     3 The first file of a chunk should be the file to have the outline/TOC present <br>

# %%
chunk_nos = [1]
chunk = 1
consecutive_postal_codes = [0]

for i in range(1, len(int_postals)):
    new_chunk_found = 0
    
    # If conditions for new chunk based on consecutine postal codes - Ref 1 
    if int_postals[i] != int_postals[i-1] + 1:
        new_chunk_found = 1
        chunk = chunk + 1
        
        
    ## If conditions for new chunk based on outline present - Ref 2 and 3    
    #if outline_present[i] == 1 and outline_present[i-1] ==1 and new_chunk_found == 0: 
    #    new_chunk_found = 1
    #    chunk = chunk + 1
        
    ## If conditions for new chunk based on TOC present - Ref 2 and 3    
    if TOC_present[i] == 1 and new_chunk_found == 0: 
        new_chunk_found = 1
        chunk = chunk + 1
        
    ### Chunk not found based on any of the above conditions
    chunk_nos.append(chunk)
        
    if int_postals[i] == int_postals[i-1] + 1:
        consecutive_postal_codes.append(1)
    else:
        consecutive_postal_codes.append(0)
        
len(chunk_nos)
len(consecutive_postal_codes)
chunk
# Out:
# 1328
# 1328
# 286

# %%
df_outlines['consecutive_postals'] = consecutive_postal_codes
df_outlines['chunk_nos'] = chunk_nos
df_outlines.head(5)
# Out:
#    file_nos  file_names                                         file_paths  \
# 0         1  A0H8C0.pdf  F:/Environmental Baseline Data/Version 3/Data/...
# 1         1  A0H8C1.pdf  F:/Environmental Baseline Data/Version 3/Data/...
# 2         1  A0H8C2.pdf  F:/Environmental Baseline Data/Version 3/Data/...
# 3         1  A0H8C3.pdf  F:/Environmental Baseline Data/Version 3/Data/...
# 4         1  A0U3G1.pdf  F:/Environmental Baseline Data/Version 3/Data/...
#
#    int_postals TOC_present  consecutive_postals  chunk_nos
# 0        20300           1                    0          1
# 1        20301           0                    1          1
# 2        20302           0                    1          1
# 3        20303           0                    1          1
# 4        52841           1                    0          2

# %% [markdown]
# ### Check for Outlines Present

# %%
# Here we are not saving or extracting the Outlines yet
# Here we are only checking if the extraction of the outline is possible or not 
outline_present = []

for pdf_path in pdf_paths:
    if 'Thum' in pdf_path:
        continue
        
    try:
        pdfread = p2.PdfFileReader(pdf_path)
        s = pdfread.outlines
        len_s = len(s)
    except:
        outline_present.append(0) # Error in reading the outline
        
    if len_s > 0:
        outline_present.append(1)
    elif len_s == 0:
        outline_present.append(0)
    
    # Error Code for s (=pdfraed.outlines) is -999
    # the negative number allows exclusivity from the if and the elif conditions above
    len_s = -999
# Out:
# PdfReadWarning: Xref table not zero-indexed. ID numbers for objects will be corrected. [pdf.py:1736]

# %%
len(file_names)
len(file_paths)
len(outline_present)
# Out:
# 1328
# 1328
# 1328

# %%
df_outlines['outline_present'] = outline_present
df_outlines.head(5)
#df_outlines.to_csv("F:/Environmental Baseline Data/Version 3/Indices/Outline_Present_htmlTOC.csv")
# Out:
#    file_nos  file_names                                         file_paths  \
# 0         1  A0H8C0.pdf  F:/Environmental Baseline Data/Version 3/Data/...
# 1         1  A0H8C1.pdf  F:/Environmental Baseline Data/Version 3/Data/...
# 2         1  A0H8C2.pdf  F:/Environmental Baseline Data/Version 3/Data/...
# 3         1  A0H8C3.pdf  F:/Environmental Baseline Data/Version 3/Data/...
# 4         1  A0U3G1.pdf  F:/Environmental Baseline Data/Version 3/Data/...
#
#    int_postals TOC_present  consecutive_postals  chunk_nos  outline_present
# 0        20300           1                    0          1                1
# 1        20301           0                    1          1                1
# 2        20302           0                    1          1                0
# 3        20303           0                    1          1                0
# 4        52841           1                    0          2                0

# %% [markdown]
# # 2. Extract Chapters from PDFs

# %% [markdown]
# ### 2 a. Table Extraction by TOC

# %%
def find_page_no(look_file_path, keyword):
    """ Given the Keyword and the PDF file, this function returs an array of 
    the page numbers on which the keyword was found"""
    object = p2.PdfFileReader(look_file_path)
    # get number of pages
    NumPages = object.getNumPages() 
    
    # chapter_key_index is set as 1 because we dont want to search for"0 Before First Chapter"
    # the array chapter_key_pages has first element 0 for the same reason
    chapter_key_index = 1
    chapter_key_page_Nos = [0]
    Flag_TOC_over = 0
    
    page_found = [-999]
    atleast_found_once = 0
    # extract text and do the search
    for i in range(0, NumPages):
        PageObj = object.getPage(i)
        #print("this is page " + str(i)) 
        try:
            Text = PageObj.extractText()
        except:
            Text = "Text could not be extracted"
        Text = Text.lower()
        Text = Text.replace("\n", "")
        # Text = Text
        # print (Text)
            
        #ResSearch = re.search(chapter_keys[chapter_key_index], Text)
        key = keyword.lower()
        if (key in Text):
            page_found.append(i)
            atleast_found_once = 1
            
    if atleast_found_once == 1:
        page_found = page_found[1:]
    return(page_found)
            

"""
def find_page_no(look_file_path, keyword):
    object = p2.PdfFileReader(look_file_path)
    # get number of pages
    NumPages = object.getNumPages() 
    
    # chapter_key_index is set as 1 because we dont want to search for"0 Before First Chapter"
    # the array chapter_key_pages has first element 0 for the same reason
    chapter_key_index = 1
    chapter_key_page_Nos = [0]
    Flag_TOC_over = 0
    
    # extract text and do the search
    for i in range(0, NumPages):
        PageObj = object.getPage(i)
        #print("this is page " + str(i)) 
        Text = PageObj.extractText()
        Text = Text.lower()
        Text = Text.replace("\n", "")
        # Text = Text
        # print (Text)
            
        #ResSearch = re.search(chapter_keys[chapter_key_index], Text)
        key = keyword.lower()
        if (key in Text):
            return i, str(look_file_path.split('/')[-1])
        
    return(-999, "") """
# Out:
# '\ndef find_page_no(look_file_path, keyword):\n    object = p2.PdfFileReader(look_file_path)\n    # get number of pages\n    NumPages = object.getNumPages() \n    \n    # chapter_key_index is set as 1 because we dont want to search for"0 Before First Chapter"\n    # the array chapter_key_pages has first element 0 for the same reason\n    chapter_key_index = 1\n    chapter_key_page_Nos = [0]\n    Flag_TOC_over = 0\n    \n    # extract text and do the search\n    for i in range(0, NumPages):\n        PageObj = object.getPage(i)\n        #print("this is page " + str(i)) \n        Text = PageObj.extractText()\n        Text = Text.lower()\n        Text = Text.replace("\n", "")\n        # Text = Text\n        # print (Text)\n            \n        #ResSearch = re.search(chapter_keys[chapter_key_index], Text)\n        key = keyword.lower()\n        if (key in Text):\n            return i, str(look_file_path.split(\'/\')[-1])\n        \n    return(-999, "") '

# %%
def path_pdf_to_text(path_pdf):
    """ This functions helps in converting the PDF file path to the Text File Path
    Input -> Path of the PDF File
    Output -> Path of the Text File, considering that the text file will be relkatively 
              in the same folder
              """
    path_Text = path_pdf.replace(" .pdf", "")
    if ".pdf" in path_Text:
        path_Text = path_pdf.replace(".pdf", "")
    #print(path_Text)
    path_Text = path_Text.replace("/PDF", "/HTML Images and Tables")
    path_Text = path_Text + "/table-of-contents.txt"
    path_Texts.append(path_Text)
    #print(path_Text)
    return (path_Text)

# %%
def head_clean(head):
    """ This functions helps in removing the textx with a lot of consecutive dots in the string 
    
    Input -> String of the chapter name 
    Eg. 1.5. Environment-Socio Assessment..................................... 34
    
    Output -> String of the chapter name which would be cleaned and can be used to extract as the 
    keys to search. 
    Eg. 1.5. Environment-Socio Assessment
    """
    
    index = 0
    for i in range(len(head)):
        if (head[i] == '.') and (head[i+1] == '.') and (head[i+2] =='.'):
            index = i
            break
        
    head_clean = head[:i]
    return head_clean

# %%
# Functtion that runs recursively to extract the outlines of the PDF files
def extract_chapter_keys(path_pdf):
    """This functions gives all the chapter keys when you give the path of the pdf as an input
    This functions works when
       - PDF is converted to HTML
       - We have extracted the Table of Contents from the HTML files
       
    Input -> Path of the PDF files
    Output -> The list of the chapter keys which woudl be used to search 
    
    This functions uses path_pdf_to_text() and head_clean() as dependent functions"""
    
    path_Text = path_pdf_to_text(path_pdf)
    print(path_Text)
    with open(path_Text) as json_file:
        data = json.load(json_file) #, encoding='utf8', errors='ignore')
        raw_TOC_text = data['raw_text'] #currently the array has a lot of strings which are not main headers 
        if len(raw_TOC_text) < 1:
            print("No TOC Found")
    
    
    chapter_keys = ["0 Before First Chapter"] 
    Flag_Appendix_Found = 0
    for head in raw_TOC_text:
        head = head.strip()
        head = re.sub(' +', ' ',head)
        if head[0].isdigit() and len(head) > 5: # assuming all the headings in the TOC are numbered
            head = head_clean(head) # removing soo many fillers '.' in the string
            
            ##########################################
            # Here, we night need to set a threshold (On the number of dots) value depending on the PDF and its TOC 
            ##########################################
            
            threshold = 2
            if head.count('.') < threshold:
                head = head.strip()
                chapter_keys.append(head)
                
            # Here we check for Appendix 
        if "Appendix" in head or "APPENDIX" in head:
            chapter_keys.append("99 Appendix")
            Flag_Appendix_Found = 1
            break
                
    if Flag_Appendix_Found == 0:
        chapter_keys.append("99 Appendix")
    return chapter_keys

# %%
def extract_TOC_chapters(file_pdf_path, current_chunk, PDF_names, 
                         PDF_locations, Chunk_No, Chapter_numbers, 
                         Chapter_texts, Chapter_keys):
    """ This function allows the use of fucntions to extract arrays of the chapter keys 
    which would be useful in extracting arrays of similar lengths to be used in Dataframes
    """
    index = -1
    chapter_keys = extract_chapter_keys(file_pdf_path)
    for chapter_key in chapter_keys:
        PDF_names.append(file_pdf_path.split('/')[-1])
        PDF_locations.append(file_pdf_path)
        Chunk_No.append(current_chunk)
        if ' ' in chapter_key:
            index = chapter_key.index(' ')
        Chapter_numbers.append(chapter_key[:index])
        Chapter_texts.append(chapter_key[index+1:])
    Chapter_keys.extend(chapter_keys)

# %%
# function to count the occourance of a keyword  
def count_occorances(lst, x):
    count = 0
    for ele in lst:
        if ele == x:
            count = count + 1
    return count

# %%
len(df_outlines)
# Out:
# 1328

# %%
PDF_names = []
PDF_locations = []
Chunk_No = []
Chapter_numbers = []
Chapter_texts = []
Chapter_keys = []
PDF_Found = []
Page_Found = []

allChaptersDF = pd.DataFrame({'PDF_names' : PDF_names, 
                              'PDF_locations' : PDF_locations,
                              'Chunk_No' : Chunk_No,
                              'Chapter_numbers' : Chapter_numbers, 
                              'Chapter_texts' : Chapter_texts, 
                              'Chapter_keys' : Chapter_keys,
                              'PDF_Found': PDF_Found,
                              'Page_Found' : Page_Found})

# %%
TOC_Found_in_Chunks = []
# This array is used to store the information wheather each of the chunk 
# has a TOC or not. 
# The length of this array would be equal to the number of chunks.
# (not equal to the number of chapters)




for current_chunk in range(34, chunk+1):
    current_df_outlines = df_outlines[df_outlines.chunk_nos == current_chunk]
    chunk_has_TOC = 0
    chunk_noOutline_hasTOC = 0
    print("Processing chunk  Number {} with {} files".format(current_chunk, len(current_df_outlines)))
    
    TOC_found = 0
    
    PDF_names = []
    PDF_locations = []
    Chunk_No = []
    Chapter_numbers = []
    Chapter_texts = []
    Chapter_keys = []
    PDF_Found = []
    Page_Found = []

    
    for i in range(len(current_df_outlines)):
        # First file in the chunk has Outline 
        if current_df_outlines.iloc[i]['TOC_present'] == 1:
            try:
                extract_TOC_chapters(current_df_outlines.iloc[i]['file_paths'], 
                                     current_chunk, PDF_names, PDF_locations, 
                                     Chunk_No, Chapter_numbers, Chapter_texts,
                                     Chapter_keys)
                #print(len(PDF_locations))
                #print(len(PDF_names))
                #print(len(Chapter_numbers))
                #print(len(Chapter_texts))
                
                if(len(Chapter_numbers) > 1):
                    TOC_found = 1
                    PDF_Found = [[-1]]
                    Page_Found = [[-1]]
                    for ikey in range(1,len(Chapter_keys)):
                        PDF_Found.append([])
                        Page_Found.append([])
                    #print(len(PDF_Found))
                
                chapter_index_search = 1        
                
            except:
                print("Error in finding the TOC")
                continue
                
            
            # Because we want to start searching from the 2nd element 
            # as the first element of the key array is a filler 
            
        if TOC_found == 1:
            
            for chapter_index_search in range(1, len(Chapter_keys)):
                print(i)
                print("search started for file {} for keyword {}".format(current_df_outlines.iloc[i]['file_paths'],
                                                                        Chapter_keys[chapter_index_search]))
                page_found = find_page_no(current_df_outlines.iloc[i]['file_paths'], 
                                          Chapter_keys[chapter_index_search])
                
                if page_found != [-999]:
                    PDF_Found[chapter_index_search].append(current_df_outlines.iloc[i]['file_paths'].split('/')[-1])
                    Page_Found[chapter_index_search].append(page_found)
                    print("Found Chapter name {} at page No. {}".format(Chapter_keys[chapter_index_search], 
                                                                    page_found))
                    chapter_index_search = chapter_index_search +1 
        
    
    while (len(PDF_Found) != len(PDF_names)):
        print("while loop started")
        if len(PDF_Found) < len(PDF_names):
            PDF_Found.append("")
            Page_Found.append("")
        else:
            break
            
    
    TOC_Found_in_Chunks.append(TOC_found) 
           
    df_chapters = pd.DataFrame({'PDF_names' : PDF_names, 
                            'PDF_locations' : PDF_locations,
                            'Chunk_No' : Chunk_No,
                            'Chapter_numbers' : Chapter_numbers, 
                            'Chapter_texts' : Chapter_texts, 
                            'Chapter_keys' : Chapter_keys,
                            'PDF_Found': PDF_Found,
                            'Page_Found' : Page_Found}, dtype= str)
    allChaptersDF = pd.concat([allChaptersDF, df_chapters])
    allChaptersDF.head(5)
# Out:
# Processing chunk  Number 34 with 5 files
# F:/Environmental Baseline Data/Version 3/Data/HTML Images and Tables/A1D5R4/table-of-contents.txt
# 0
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R4.pdf for keyword 1.0 INTRODUCTION
# Found Chapter name 1.0 INTRODUCTION at page No. [2, 11, 19, 21]
# 0
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R4.pdf for keyword 1.1 Overview
# Found Chapter name 1.1 Overview at page No. [11, 19]
# 0
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R4.pdf for keyword 1.2 Project Justification
# Found Chapter name 1.2 Project Justification at page No. [11, 19]
# 0
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R4.pdf for keyword 1.3 Regulatory Framework
# Found Chapter name 1.3 Regulatory Framework at page No. [11, 19]
# 0
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R4.pdf for keyword 1.4 Purpose of the Document
# Found Chapter name 1.4 Purpose of the Document at page No. [11, 21]
# 0
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R4.pdf for keyword 1.5 Project Team
# Found Chapter name 1.5 Project Team at page No. [11, 22]
# 0
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R4.pdf for keyword 1.6 Concordance with the NEB Filing Manual
# Found Chapter name 1.6 Concordance with the NEB Filing Manual at page No. [11, 22]
# 0
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R4.pdf for keyword 2.0 PROJECT DESCRIPTION
# Found Chapter name 2.0 PROJECT DESCRIPTION at page No. [2, 11, 21, 26]
# 0
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R4.pdf for keyword 2.1 Project Purpose
# Found Chapter name 2.1 Project Purpose at page No. [11, 26]
# 0
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R4.pdf for keyword 2.2 Alternatives to the Project
# Found Chapter name 2.2 Alternatives to the Project at page No. [11, 26]
# 0
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R4.pdf for keyword 2.3 Alternative Means to Carry Out the Project
# Found Chapter name 2.3 Alternative Means to Carry Out the Project at page No. [11, 26]
# 0
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R4.pdf for keyword 2.4 Components of the Project and Location of the Project
# Found Chapter name 2.4 Components of the Project and Location of the Project at page No. [11, 27]
# 0
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R4.pdf for keyword 2.5 Construction
# Found Chapter name 2.5 Construction at page No. [11, 16, 29]
# 0
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R4.pdf for keyword 2.6 Operations and Ongoing Maintenance
# Found Chapter name 2.6 Operations and Ongoing Maintenance at page No. [11, 34]
# 0
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R4.pdf for keyword 2.7 Decommissioning and Abandonment
# Found Chapter name 2.7 Decommissioning and Abandonment at page No. [11, 37]
# 0
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R4.pdf for keyword 2.8 References
# Found Chapter name 2.8 References at page No. [11, 37]
# 0
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R4.pdf for keyword 3.0 PUBLIC CONSULTATION
# Found Chapter name 3.0 PUBLIC CONSULTATION at page No. [2, 11, 21, 38]
# 0
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R4.pdf for keyword 4.0 ROUTE AND FACILITY SITE SELECTION
# Found Chapter name 4.0 ROUTE AND FACILITY SITE SELECTION at page No. [11]
# 0
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R4.pdf for keyword 4.1 Project Siting Criteria and Route Alternatives
# Found Chapter name 4.1 Project Siting Criteria and Route Alternatives at page No. [11]
# 0
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R4.pdf for keyword 4.2 Preferred Pipeline Route Refinement
# Found Chapter name 4.2 Preferred Pipeline Route Refinement at page No. [11]
# 0
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R4.pdf for keyword 4.3 Pipeline Appurtenances Siting
# Found Chapter name 4.3 Pipeline Appurtenances Siting at page No. [11]
# 0
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R4.pdf for keyword 4.4 Temporary Facility Siting
# Found Chapter name 4.4 Temporary Facility Siting at page No. [11]
# 0
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R4.pdf for keyword 4.5 References
# Found Chapter name 4.5 References at page No. [12]
# 0
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R4.pdf for keyword 5.0 ENVIRONMENTAL AND SOCIO-ECONOMIC SETTING
# Found Chapter name 5.0 ENVIRONMENTAL AND SOCIO-ECONOMIC SETTING at page No. [2, 12, 21]
# 0
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R4.pdf for keyword 5.1 Physical Environment
# Found Chapter name 5.1 Physical Environment at page No. [12]
# 0
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R4.pdf for keyword 5.2 Soil and Soil Productivity
# Found Chapter name 5.2 Soil and Soil Productivity at page No. [12]
# 0
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R4.pdf for keyword 5.3 Water Quality and Quantity
# Found Chapter name 5.3 Water Quality and Quantity at page No. [12]
# 0
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R4.pdf for keyword 5.4 Air Quality
# Found Chapter name 5.4 Air Quality at page No. [12]
# 0
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R4.pdf for keyword 5.5 Acoustic Environment
# Found Chapter name 5.5 Acoustic Environment at page No. [12]
# 0
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R4.pdf for keyword 5.6 Fish and Fish Habitat
# Found Chapter name 5.6 Fish and Fish Habitat at page No. [12]
# 0
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R4.pdf for keyword 5.7 Wetlands
# Found Chapter name 5.7 Wetlands at page No. [12]
# 0
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R4.pdf for keyword 5.8 Vegetation and Forest Health
# Found Chapter name 5.8 Vegetation and Forest Health at page No. [12]
# 0
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R4.pdf for keyword 5.9 Wildlife and Wildlife Habitat
# Found Chapter name 5.9 Wildlife and Wildlife Habitat at page No. [12]
# 0
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R4.pdf for keyword 5.10 Species at Risk
# Found Chapter name 5.10 Species at Risk at page No. [12]
# 0
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R4.pdf for keyword 5.11 Human Occupancy and Resource Use
# Found Chapter name 5.11 Human Occupancy and Resource Use at page No. [12]
# 0
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R4.pdf for keyword 5.12 Historical Resources
# Found Chapter name 5.12 Historical Resources at page No. [13]
# 0
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R4.pdf for keyword 5.13 Traditional Land and Resource Use
# Found Chapter name 5.13 Traditional Land and Resource Use at page No. [13]
# 0
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R4.pdf for keyword 5.14 Social and Cultural Well-Being
# Found Chapter name 5.14 Social and Cultural Well-Being at page No. [13]
# 0
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R4.pdf for keyword 5.15 Human Health
# Found Chapter name 5.15 Human Health at page No. [13]
# 0
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R4.pdf for keyword 5.16 Infrastructure and Services
# Found Chapter name 5.16 Infrastructure and Services at page No. [13]
# 0
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R4.pdf for keyword 5.17 Employment and Economy
# Found Chapter name 5.17 Employment and Economy at page No. [13]
# 0
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R4.pdf for keyword 5.18 References
# Found Chapter name 5.18 References at page No. [13]
# 0
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R4.pdf for keyword 6.0 ENVIRONMENTAL AND SOCIO-ECONOMIC EFFECTS ASSESSMENT
# Found Chapter name 6.0 ENVIRONMENTAL AND SOCIO-ECONOMIC EFFECTS ASSESSMENT at page No. [2, 13, 21]
# 0
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R4.pdf for keyword 6.1 Methodology
# Found Chapter name 6.1 Methodology at page No. [13]
# 0
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R4.pdf for keyword 6.2 Effects Assessment - Pipeline Construction and Operation
# Found Chapter name 6.2 Effects Assessment - Pipeline Construction and Operation at page No. [13]
# 0
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R4.pdf for keyword 6.3 Effects Assessment - Permanent Facilities Construction and Operation
# Found Chapter name 6.3 Effects Assessment - Permanent Facilities Construction and Operation at page No. [13]
# 0
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R4.pdf for keyword 6.4 Effects Assessment - Decommissioning and Abandonment
# Found Chapter name 6.4 Effects Assessment - Decommissioning and Abandonment at page No. [14]
# 0
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R4.pdf for keyword 6.5 Effects of the Environment on the Project
# Found Chapter name 6.5 Effects of the Environment on the Project at page No. [14]
# 0
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R4.pdf for keyword 6.6 Summary of Environmental and Socio-Economic Effects Assessment
# Found Chapter name 6.6 Summary of Environmental and Socio-Economic Effects Assessment at page No. [14]
# 0
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R4.pdf for keyword 6.7 References
# Found Chapter name 6.7 References at page No. [14]
# 0
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R4.pdf for keyword 7.0 CUMULATIVE EFFECTS ASSESSMENT
# Found Chapter name 7.0 CUMULATIVE EFFECTS ASSESSMENT at page No. [2, 14, 21]
# 0
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R4.pdf for keyword 7.1 Methodology
# Found Chapter name 7.1 Methodology at page No. [14]
# 0
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R4.pdf for keyword 7.2 Cumulative Effects Assessment - Project Construction and Operation
# 0
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R4.pdf for keyword 7.3 Summary of the Assessment of Potential Cumulative Residual Effects of th
# Found Chapter name 7.3 Summary of the Assessment of Potential Cumulative Residual Effects of th at page No. [14]
# 0
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R4.pdf for keyword 7.4 References
# Found Chapter name 7.4 References at page No. [14]
# 0
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R4.pdf for keyword 8.0 INSPECTION, MONITORING AND FOLLOW-UP
# Found Chapter name 8.0 INSPECTION, MONITORING AND FOLLOW-UP at page No. [2, 14, 21]
# 0
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R4.pdf for keyword 8.1 Environmental Policy
# Found Chapter name 8.1 Environmental Policy at page No. [14]
# 0
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R4.pdf for keyword 8.2 Environmental Protection Planning for Construction
# Found Chapter name 8.2 Environmental Protection Planning for Construction at page No. [15]
# 0
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R4.pdf for keyword 8.3 Environmental Education during Construction
# Found Chapter name 8.3 Environmental Education during Construction at page No. [15]
# 0
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R4.pdf for keyword 8.4 Environmental Inspection during Construction
# Found Chapter name 8.4 Environmental Inspection during Construction at page No. [15]
# 0
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R4.pdf for keyword 8.5 Issue Monitoring During Construction
# Found Chapter name 8.5 Issue Monitoring During Construction at page No. [15]
# 0
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R4.pdf for keyword 8.6 Post-Construction Monitoring
# Found Chapter name 8.6 Post-Construction Monitoring at page No. [15]
# 0
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R4.pdf for keyword 8.7 Company Management Plans
# Found Chapter name 8.7 Company Management Plans at page No. [15]
# 0
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R4.pdf for keyword 8.8 References
# Found Chapter name 8.8 References at page No. [15]
# 0
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R4.pdf for keyword 9.0 SUPPLEMENTAL STUDIES
# Found Chapter name 9.0 SUPPLEMENTAL STUDIES at page No. [2, 15, 22]
# 0
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R4.pdf for keyword 9.1 Introduction
# Found Chapter name 9.1 Introduction at page No. [15]
# 0
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R4.pdf for keyword 9.2 Geotechnical Assessment
# Found Chapter name 9.2 Geotechnical Assessment at page No. [15]
# 0
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R4.pdf for keyword 9.3 Soil Survey
# Found Chapter name 9.3 Soil Survey at page No. [15]
# 0
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R4.pdf for keyword 9.4 Rare Vascular Plant and Ecological Community Surveys
# Found Chapter name 9.4 Rare Vascular Plant and Ecological Community Surveys at page No. [15]
# 0
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R4.pdf for keyword 9.5 Weed Survey
# Found Chapter name 9.5 Weed Survey at page No. [15]
# 0
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R4.pdf for keyword 9.6 Wildlife and Wildlife Habitat Surveys for Species of Concern
# Found Chapter name 9.6 Wildlife and Wildlife Habitat Surveys for Species of Concern at page No. [15]
# 0
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R4.pdf for keyword 9.7 Archaeological Impact Assessment
# Found Chapter name 9.7 Archaeological Impact Assessment at page No. [15]
# 0
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R4.pdf for keyword 9.8 Detailed Watercourse Crossing and Contingency Plans
# Found Chapter name 9.8 Detailed Watercourse Crossing and Contingency Plans at page No. [15]
# 0
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R4.pdf for keyword 9.9 Wetland Characterization
# Found Chapter name 9.9 Wetland Characterization at page No. [15]
# 0
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R4.pdf for keyword 9.10 Fish and Fish Habitat Surveys
# Found Chapter name 9.10 Fish and Fish Habitat Surveys at page No. [15]
# 0
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R4.pdf for keyword 9.11 Environmental Review of Temporary Facilities
# Found Chapter name 9.11 Environmental Review of Temporary Facilities at page No. [15]
# 0
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R4.pdf for keyword 9.12 References
# Found Chapter name 9.12 References at page No. [15]
# 0
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R4.pdf for keyword 10.0 CONCLUSION
# Found Chapter name 10.0 CONCLUSION at page No. [2, 15, 22]
# 0
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R4.pdf for keyword 99 Appendix
# 1
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R5.pdf for keyword 1.0 INTRODUCTION
# 1
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R5.pdf for keyword 1.1 Overview
# 1
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R5.pdf for keyword 1.2 Project Justification
# 1
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R5.pdf for keyword 1.3 Regulatory Framework
# 1
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R5.pdf for keyword 1.4 Purpose of the Document
# 1
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R5.pdf for keyword 1.5 Project Team
# 1
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R5.pdf for keyword 1.6 Concordance with the NEB Filing Manual
# 1
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R5.pdf for keyword 2.0 PROJECT DESCRIPTION
# 1
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R5.pdf for keyword 2.1 Project Purpose
# 1
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R5.pdf for keyword 2.2 Alternatives to the Project
# 1
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R5.pdf for keyword 2.3 Alternative Means to Carry Out the Project
# 1
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R5.pdf for keyword 2.4 Components of the Project and Location of the Project
# 1
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R5.pdf for keyword 2.5 Construction
# 1
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R5.pdf for keyword 2.6 Operations and Ongoing Maintenance
# 1
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R5.pdf for keyword 2.7 Decommissioning and Abandonment
# 1
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R5.pdf for keyword 2.8 References
# 1
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R5.pdf for keyword 3.0 PUBLIC CONSULTATION
# 1
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R5.pdf for keyword 4.0 ROUTE AND FACILITY SITE SELECTION
# Found Chapter name 4.0 ROUTE AND FACILITY SITE SELECTION at page No. [0]
# 1
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R5.pdf for keyword 4.1 Project Siting Criteria and Route Alternatives
# Found Chapter name 4.1 Project Siting Criteria and Route Alternatives at page No. [0]
# 1
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R5.pdf for keyword 4.2 Preferred Pipeline Route Refinement
# Found Chapter name 4.2 Preferred Pipeline Route Refinement at page No. [8]
# 1
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R5.pdf for keyword 4.3 Pipeline Appurtenances Siting
# Found Chapter name 4.3 Pipeline Appurtenances Siting at page No. [8]
# 1
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R5.pdf for keyword 4.4 Temporary Facility Siting
# Found Chapter name 4.4 Temporary Facility Siting at page No. [11]
# 1
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R5.pdf for keyword 4.5 References
# Found Chapter name 4.5 References at page No. [12]
# 1
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R5.pdf for keyword 5.0 ENVIRONMENTAL AND SOCIO-ECONOMIC SETTING
# 1
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R5.pdf for keyword 5.1 Physical Environment
# 1
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R5.pdf for keyword 5.2 Soil and Soil Productivity
# 1
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R5.pdf for keyword 5.3 Water Quality and Quantity
# 1
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R5.pdf for keyword 5.4 Air Quality
# 1
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R5.pdf for keyword 5.5 Acoustic Environment
# 1
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R5.pdf for keyword 5.6 Fish and Fish Habitat
# 1
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R5.pdf for keyword 5.7 Wetlands
# 1
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R5.pdf for keyword 5.8 Vegetation and Forest Health
# 1
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R5.pdf for keyword 5.9 Wildlife and Wildlife Habitat
# 1
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R5.pdf for keyword 5.10 Species at Risk
# 1
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R5.pdf for keyword 5.11 Human Occupancy and Resource Use
# 1
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R5.pdf for keyword 5.12 Historical Resources
# 1
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R5.pdf for keyword 5.13 Traditional Land and Resource Use
# 1
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R5.pdf for keyword 5.14 Social and Cultural Well-Being
# 1
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R5.pdf for keyword 5.15 Human Health
# 1
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R5.pdf for keyword 5.16 Infrastructure and Services
# 1
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R5.pdf for keyword 5.17 Employment and Economy
# 1
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R5.pdf for keyword 5.18 References
# 1
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R5.pdf for keyword 6.0 ENVIRONMENTAL AND SOCIO-ECONOMIC EFFECTS ASSESSMENT
# 1
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R5.pdf for keyword 6.1 Methodology
# 1
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R5.pdf for keyword 6.2 Effects Assessment - Pipeline Construction and Operation
# 1
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R5.pdf for keyword 6.3 Effects Assessment - Permanent Facilities Construction and Operation
# 1
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R5.pdf for keyword 6.4 Effects Assessment - Decommissioning and Abandonment
# 1
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R5.pdf for keyword 6.5 Effects of the Environment on the Project
# 1
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R5.pdf for keyword 6.6 Summary of Environmental and Socio-Economic Effects Assessment
# 1
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R5.pdf for keyword 6.7 References
# 1
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R5.pdf for keyword 7.0 CUMULATIVE EFFECTS ASSESSMENT
# 1
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R5.pdf for keyword 7.1 Methodology
# 1
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R5.pdf for keyword 7.2 Cumulative Effects Assessment - Project Construction and Operation
# 1
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R5.pdf for keyword 7.3 Summary of the Assessment of Potential Cumulative Residual Effects of th
# 1
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R5.pdf for keyword 7.4 References
# 1
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R5.pdf for keyword 8.0 INSPECTION, MONITORING AND FOLLOW-UP
# 1
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R5.pdf for keyword 8.1 Environmental Policy
# 1
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R5.pdf for keyword 8.2 Environmental Protection Planning for Construction
# 1
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R5.pdf for keyword 8.3 Environmental Education during Construction
# 1
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R5.pdf for keyword 8.4 Environmental Inspection during Construction
# 1
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R5.pdf for keyword 8.5 Issue Monitoring During Construction
# 1
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R5.pdf for keyword 8.6 Post-Construction Monitoring
# 1
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R5.pdf for keyword 8.7 Company Management Plans
# 1
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R5.pdf for keyword 8.8 References
# 1
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R5.pdf for keyword 9.0 SUPPLEMENTAL STUDIES
# 1
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R5.pdf for keyword 9.1 Introduction
# 1
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R5.pdf for keyword 9.2 Geotechnical Assessment
# 1
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R5.pdf for keyword 9.3 Soil Survey
# 1
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R5.pdf for keyword 9.4 Rare Vascular Plant and Ecological Community Surveys
# 1
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R5.pdf for keyword 9.5 Weed Survey
# 1
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R5.pdf for keyword 9.6 Wildlife and Wildlife Habitat Surveys for Species of Concern
# 1
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R5.pdf for keyword 9.7 Archaeological Impact Assessment
# 1
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R5.pdf for keyword 9.8 Detailed Watercourse Crossing and Contingency Plans
# 1
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R5.pdf for keyword 9.9 Wetland Characterization
# 1
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R5.pdf for keyword 9.10 Fish and Fish Habitat Surveys
# 1
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R5.pdf for keyword 9.11 Environmental Review of Temporary Facilities
# 1
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R5.pdf for keyword 9.12 References
# 1
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R5.pdf for keyword 10.0 CONCLUSION
# 1
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R5.pdf for keyword 99 Appendix
# 2
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R6.pdf for keyword 1.0 INTRODUCTION
# 2
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R6.pdf for keyword 1.1 Overview
# 2
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R6.pdf for keyword 1.2 Project Justification
# 2
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R6.pdf for keyword 1.3 Regulatory Framework
# 2
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R6.pdf for keyword 1.4 Purpose of the Document
# 2
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R6.pdf for keyword 1.5 Project Team
# 2
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R6.pdf for keyword 1.6 Concordance with the NEB Filing Manual
# 2
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R6.pdf for keyword 2.0 PROJECT DESCRIPTION
# 2
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R6.pdf for keyword 2.1 Project Purpose
# 2
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R6.pdf for keyword 2.2 Alternatives to the Project
# 2
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R6.pdf for keyword 2.3 Alternative Means to Carry Out the Project
# 2
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R6.pdf for keyword 2.4 Components of the Project and Location of the Project
# 2
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R6.pdf for keyword 2.5 Construction
# 2
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R6.pdf for keyword 2.6 Operations and Ongoing Maintenance
# 2
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R6.pdf for keyword 2.7 Decommissioning and Abandonment
# 2
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R6.pdf for keyword 2.8 References
# 2
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R6.pdf for keyword 3.0 PUBLIC CONSULTATION
# 2
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R6.pdf for keyword 4.0 ROUTE AND FACILITY SITE SELECTION
# 2
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R6.pdf for keyword 4.1 Project Siting Criteria and Route Alternatives
# 2
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R6.pdf for keyword 4.2 Preferred Pipeline Route Refinement
# 2
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R6.pdf for keyword 4.3 Pipeline Appurtenances Siting
# 2
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R6.pdf for keyword 4.4 Temporary Facility Siting
# 2
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R6.pdf for keyword 4.5 References
# 2
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R6.pdf for keyword 5.0 ENVIRONMENTAL AND SOCIO-ECONOMIC SETTING
# Found Chapter name 5.0 ENVIRONMENTAL AND SOCIO-ECONOMIC SETTING at page No. [0]
# 2
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R6.pdf for keyword 5.1 Physical Environment
# Found Chapter name 5.1 Physical Environment at page No. [0]
# 2
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R6.pdf for keyword 5.2 Soil and Soil Productivity
# Found Chapter name 5.2 Soil and Soil Productivity at page No. [5]
# 2
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R6.pdf for keyword 5.3 Water Quality and Quantity
# Found Chapter name 5.3 Water Quality and Quantity at page No. [7]
# 2
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R6.pdf for keyword 5.4 Air Quality
# Found Chapter name 5.4 Air Quality at page No. [12]
# 2
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R6.pdf for keyword 5.5 Acoustic Environment
# Found Chapter name 5.5 Acoustic Environment at page No. [15]
# 2
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R6.pdf for keyword 5.6 Fish and Fish Habitat
# Found Chapter name 5.6 Fish and Fish Habitat at page No. [15]
# 2
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R6.pdf for keyword 5.7 Wetlands
# Found Chapter name 5.7 Wetlands at page No. [20]
# 2
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R6.pdf for keyword 5.8 Vegetation and Forest Health
# Found Chapter name 5.8 Vegetation and Forest Health at page No. [22]
# 2
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R6.pdf for keyword 5.9 Wildlife and Wildlife Habitat
# Found Chapter name 5.9 Wildlife and Wildlife Habitat at page No. [24]
# 2
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R6.pdf for keyword 5.10 Species at Risk
# Found Chapter name 5.10 Species at Risk at page No. [28]
# 2
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R6.pdf for keyword 5.11 Human Occupancy and Resource Use
# Found Chapter name 5.11 Human Occupancy and Resource Use at page No. [30]
# 2
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R6.pdf for keyword 5.12 Historical Resources
# Found Chapter name 5.12 Historical Resources at page No. [34]
# 2
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R6.pdf for keyword 5.13 Traditional Land and Resource Use
# Found Chapter name 5.13 Traditional Land and Resource Use at page No. [35]
# 2
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R6.pdf for keyword 5.14 Social and Cultural Well-Being
# Found Chapter name 5.14 Social and Cultural Well-Being at page No. [35]
# 2
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R6.pdf for keyword 5.15 Human Health
# Found Chapter name 5.15 Human Health at page No. [36]
# 2
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R6.pdf for keyword 5.16 Infrastructure and Services
# Found Chapter name 5.16 Infrastructure and Services at page No. [36]
# 2
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R6.pdf for keyword 5.17 Employment and Economy
# Found Chapter name 5.17 Employment and Economy at page No. [40]
# 2
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R6.pdf for keyword 5.18 References
# Found Chapter name 5.18 References at page No. [42]
# 2
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R6.pdf for keyword 6.0 ENVIRONMENTAL AND SOCIO-ECONOMIC EFFECTS ASSESSMENT
# 2
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R6.pdf for keyword 6.1 Methodology
# 2
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R6.pdf for keyword 6.2 Effects Assessment - Pipeline Construction and Operation
# 2
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R6.pdf for keyword 6.3 Effects Assessment - Permanent Facilities Construction and Operation
# 2
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R6.pdf for keyword 6.4 Effects Assessment - Decommissioning and Abandonment
# 2
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R6.pdf for keyword 6.5 Effects of the Environment on the Project
# 2
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R6.pdf for keyword 6.6 Summary of Environmental and Socio-Economic Effects Assessment
# 2
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R6.pdf for keyword 6.7 References
# 2
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R6.pdf for keyword 7.0 CUMULATIVE EFFECTS ASSESSMENT
# 2
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R6.pdf for keyword 7.1 Methodology
# 2
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R6.pdf for keyword 7.2 Cumulative Effects Assessment - Project Construction and Operation
# 2
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R6.pdf for keyword 7.3 Summary of the Assessment of Potential Cumulative Residual Effects of th
# 2
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R6.pdf for keyword 7.4 References
# 2
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R6.pdf for keyword 8.0 INSPECTION, MONITORING AND FOLLOW-UP
# 2
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R6.pdf for keyword 8.1 Environmental Policy
# 2
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R6.pdf for keyword 8.2 Environmental Protection Planning for Construction
# 2
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R6.pdf for keyword 8.3 Environmental Education during Construction
# 2
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R6.pdf for keyword 8.4 Environmental Inspection during Construction
# 2
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R6.pdf for keyword 8.5 Issue Monitoring During Construction
# 2
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R6.pdf for keyword 8.6 Post-Construction Monitoring
# 2
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R6.pdf for keyword 8.7 Company Management Plans
# 2
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R6.pdf for keyword 8.8 References
# 2
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R6.pdf for keyword 9.0 SUPPLEMENTAL STUDIES
# 2
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R6.pdf for keyword 9.1 Introduction
# 2
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R6.pdf for keyword 9.2 Geotechnical Assessment
# 2
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R6.pdf for keyword 9.3 Soil Survey
# 2
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R6.pdf for keyword 9.4 Rare Vascular Plant and Ecological Community Surveys
# 2
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R6.pdf for keyword 9.5 Weed Survey
# 2
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R6.pdf for keyword 9.6 Wildlife and Wildlife Habitat Surveys for Species of Concern
# 2
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R6.pdf for keyword 9.7 Archaeological Impact Assessment
# 2
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R6.pdf for keyword 9.8 Detailed Watercourse Crossing and Contingency Plans
# 2
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R6.pdf for keyword 9.9 Wetland Characterization
# 2
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R6.pdf for keyword 9.10 Fish and Fish Habitat Surveys
# 2
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R6.pdf for keyword 9.11 Environmental Review of Temporary Facilities
# 2
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R6.pdf for keyword 9.12 References
# 2
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R6.pdf for keyword 10.0 CONCLUSION
# 2
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R6.pdf for keyword 99 Appendix
# 3
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R7.pdf for keyword 1.0 INTRODUCTION
# 3
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R7.pdf for keyword 1.1 Overview
# 3
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R7.pdf for keyword 1.2 Project Justification
# 3
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R7.pdf for keyword 1.3 Regulatory Framework
# 3
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R7.pdf for keyword 1.4 Purpose of the Document
# 3
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R7.pdf for keyword 1.5 Project Team
# 3
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R7.pdf for keyword 1.6 Concordance with the NEB Filing Manual
# 3
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R7.pdf for keyword 2.0 PROJECT DESCRIPTION
# 3
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R7.pdf for keyword 2.1 Project Purpose
# 3
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R7.pdf for keyword 2.2 Alternatives to the Project
# 3
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R7.pdf for keyword 2.3 Alternative Means to Carry Out the Project
# 3
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R7.pdf for keyword 2.4 Components of the Project and Location of the Project
# 3
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R7.pdf for keyword 2.5 Construction
# 3
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R7.pdf for keyword 2.6 Operations and Ongoing Maintenance
# 3
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R7.pdf for keyword 2.7 Decommissioning and Abandonment
# 3
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R7.pdf for keyword 2.8 References
# 3
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R7.pdf for keyword 3.0 PUBLIC CONSULTATION
# 3
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R7.pdf for keyword 4.0 ROUTE AND FACILITY SITE SELECTION
# 3
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R7.pdf for keyword 4.1 Project Siting Criteria and Route Alternatives
# 3
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R7.pdf for keyword 4.2 Preferred Pipeline Route Refinement
# 3
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R7.pdf for keyword 4.3 Pipeline Appurtenances Siting
# 3
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R7.pdf for keyword 4.4 Temporary Facility Siting
# 3
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R7.pdf for keyword 4.5 References
# 3
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R7.pdf for keyword 5.0 ENVIRONMENTAL AND SOCIO-ECONOMIC SETTING
# 3
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R7.pdf for keyword 5.1 Physical Environment
# 3
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R7.pdf for keyword 5.2 Soil and Soil Productivity
# 3
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R7.pdf for keyword 5.3 Water Quality and Quantity
# 3
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R7.pdf for keyword 5.4 Air Quality
# 3
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R7.pdf for keyword 5.5 Acoustic Environment
# 3
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R7.pdf for keyword 5.6 Fish and Fish Habitat
# 3
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R7.pdf for keyword 5.7 Wetlands
# 3
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R7.pdf for keyword 5.8 Vegetation and Forest Health
# 3
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R7.pdf for keyword 5.9 Wildlife and Wildlife Habitat
# 3
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R7.pdf for keyword 5.10 Species at Risk
# 3
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R7.pdf for keyword 5.11 Human Occupancy and Resource Use
# 3
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R7.pdf for keyword 5.12 Historical Resources
# 3
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R7.pdf for keyword 5.13 Traditional Land and Resource Use
# 3
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R7.pdf for keyword 5.14 Social and Cultural Well-Being
# 3
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R7.pdf for keyword 5.15 Human Health
# 3
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R7.pdf for keyword 5.16 Infrastructure and Services
# 3
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R7.pdf for keyword 5.17 Employment and Economy
# 3
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R7.pdf for keyword 5.18 References
# 3
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R7.pdf for keyword 6.0 ENVIRONMENTAL AND SOCIO-ECONOMIC EFFECTS ASSESSMENT
# Found Chapter name 6.0 ENVIRONMENTAL AND SOCIO-ECONOMIC EFFECTS ASSESSMENT at page No. [0]
# 3
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R7.pdf for keyword 6.1 Methodology
# Found Chapter name 6.1 Methodology at page No. [0]
# 3
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R7.pdf for keyword 6.2 Effects Assessment - Pipeline Construction and Operation
# Found Chapter name 6.2 Effects Assessment - Pipeline Construction and Operation at page No. [6]
# 3
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R7.pdf for keyword 6.3 Effects Assessment - Permanent Facilities Construction and Operation
# Found Chapter name 6.3 Effects Assessment - Permanent Facilities Construction and Operation at page No. [49]
# 3
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R7.pdf for keyword 6.4 Effects Assessment - Decommissioning and Abandonment
# Found Chapter name 6.4 Effects Assessment - Decommissioning and Abandonment at page No. [52]
# 3
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R7.pdf for keyword 6.5 Effects of the Environment on the Project
# Found Chapter name 6.5 Effects of the Environment on the Project at page No. [54]
# 3
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R7.pdf for keyword 6.6 Summary of Environmental and Socio-Economic Effects Assessment
# Found Chapter name 6.6 Summary of Environmental and Socio-Economic Effects Assessment at page No. [57]
# 3
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R7.pdf for keyword 6.7 References
# Found Chapter name 6.7 References at page No. [57]
# 3
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R7.pdf for keyword 7.0 CUMULATIVE EFFECTS ASSESSMENT
# 3
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R7.pdf for keyword 7.1 Methodology
# 3
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R7.pdf for keyword 7.2 Cumulative Effects Assessment - Project Construction and Operation
# 3
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R7.pdf for keyword 7.3 Summary of the Assessment of Potential Cumulative Residual Effects of th
# 3
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R7.pdf for keyword 7.4 References
# 3
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R7.pdf for keyword 8.0 INSPECTION, MONITORING AND FOLLOW-UP
# 3
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R7.pdf for keyword 8.1 Environmental Policy
# 3
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R7.pdf for keyword 8.2 Environmental Protection Planning for Construction
# 3
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R7.pdf for keyword 8.3 Environmental Education during Construction
# 3
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R7.pdf for keyword 8.4 Environmental Inspection during Construction
# 3
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R7.pdf for keyword 8.5 Issue Monitoring During Construction
# 3
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R7.pdf for keyword 8.6 Post-Construction Monitoring
# 3
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R7.pdf for keyword 8.7 Company Management Plans
# 3
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R7.pdf for keyword 8.8 References
# 3
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1D5R7.pdf for keyword 9.0 SUPPLEMENTAL STUDIES
# 3
# ...
# 22
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W2.pdf for keyword 2.8 Accidents, Malfunctions and Unplanned Events
# 22
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W2.pdf for keyword 3 Consultation
# 22
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W2.pdf for keyword 3.1 Approach
# 22
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W2.pdf for keyword 3.2 Regulatory Consultation
# 22
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W2.pdf for keyword 3.3 Communities and Landowners Consultation
# 22
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W2.pdf for keyword 3.4 Aboriginal Engagement
# 22
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W2.pdf for keyword 3.5 Summary of Issues and Concerns
# 22
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W2.pdf for keyword 99 Appendix
# 23
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W3.pdf for keyword 1 Introduction
# 23
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W3.pdf for keyword 1.1 Purpose of the Environmental and Socio-Economic Assessment Report
# 23
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W3.pdf for keyword 1.2 Project Overview
# 23
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W3.pdf for keyword 1.3 Proponents
# 23
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W3.pdf for keyword 1.4 Project Components
# 23
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W3.pdf for keyword 1.5 Regulatory Context
# 23
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W3.pdf for keyword 1.6 Table of Concordance
# 23
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W3.pdf for keyword 1.7 Organization of the Environmental and Socio-economic Assessment Report
# 23
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W3.pdf for keyword 2 Project Description
# 23
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W3.pdf for keyword 2.1 Project Purpose and Need
# 23
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W3.pdf for keyword 2.2 Alternatives to the Project
# 23
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W3.pdf for keyword 2.3 Alternative Means
# 23
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W3.pdf for keyword 2.4 Project Components
# 23
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W3.pdf for keyword 2.5 Facilities
# 23
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W3.pdf for keyword 2.6 Operations and Maintenance
# 23
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W3.pdf for keyword 2.7 Decomissioning and Abandonment
# 23
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W3.pdf for keyword 2.8 Accidents, Malfunctions and Unplanned Events
# 23
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W3.pdf for keyword 3 Consultation
# 23
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W3.pdf for keyword 3.1 Approach
# 23
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W3.pdf for keyword 3.2 Regulatory Consultation
# 23
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W3.pdf for keyword 3.3 Communities and Landowners Consultation
# 23
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W3.pdf for keyword 3.4 Aboriginal Engagement
# 23
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W3.pdf for keyword 3.5 Summary of Issues and Concerns
# 23
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W3.pdf for keyword 99 Appendix
# 24
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W4.pdf for keyword 1 Introduction
# 24
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W4.pdf for keyword 1.1 Purpose of the Environmental and Socio-Economic Assessment Report
# 24
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W4.pdf for keyword 1.2 Project Overview
# 24
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W4.pdf for keyword 1.3 Proponents
# 24
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W4.pdf for keyword 1.4 Project Components
# 24
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W4.pdf for keyword 1.5 Regulatory Context
# 24
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W4.pdf for keyword 1.6 Table of Concordance
# 24
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W4.pdf for keyword 1.7 Organization of the Environmental and Socio-economic Assessment Report
# 24
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W4.pdf for keyword 2 Project Description
# 24
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W4.pdf for keyword 2.1 Project Purpose and Need
# 24
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W4.pdf for keyword 2.2 Alternatives to the Project
# 24
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W4.pdf for keyword 2.3 Alternative Means
# 24
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W4.pdf for keyword 2.4 Project Components
# 24
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W4.pdf for keyword 2.5 Facilities
# 24
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W4.pdf for keyword 2.6 Operations and Maintenance
# 24
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W4.pdf for keyword 2.7 Decomissioning and Abandonment
# 24
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W4.pdf for keyword 2.8 Accidents, Malfunctions and Unplanned Events
# 24
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W4.pdf for keyword 3 Consultation
# 24
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W4.pdf for keyword 3.1 Approach
# 24
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W4.pdf for keyword 3.2 Regulatory Consultation
# 24
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W4.pdf for keyword 3.3 Communities and Landowners Consultation
# 24
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W4.pdf for keyword 3.4 Aboriginal Engagement
# 24
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W4.pdf for keyword 3.5 Summary of Issues and Concerns
# 24
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W4.pdf for keyword 99 Appendix
# 25
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W5.pdf for keyword 1 Introduction
# 25
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W5.pdf for keyword 1.1 Purpose of the Environmental and Socio-Economic Assessment Report
# 25
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W5.pdf for keyword 1.2 Project Overview
# 25
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W5.pdf for keyword 1.3 Proponents
# 25
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W5.pdf for keyword 1.4 Project Components
# 25
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W5.pdf for keyword 1.5 Regulatory Context
# 25
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W5.pdf for keyword 1.6 Table of Concordance
# 25
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W5.pdf for keyword 1.7 Organization of the Environmental and Socio-economic Assessment Report
# 25
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W5.pdf for keyword 2 Project Description
# 25
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W5.pdf for keyword 2.1 Project Purpose and Need
# 25
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W5.pdf for keyword 2.2 Alternatives to the Project
# 25
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W5.pdf for keyword 2.3 Alternative Means
# 25
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W5.pdf for keyword 2.4 Project Components
# 25
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W5.pdf for keyword 2.5 Facilities
# 25
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W5.pdf for keyword 2.6 Operations and Maintenance
# 25
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W5.pdf for keyword 2.7 Decomissioning and Abandonment
# 25
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W5.pdf for keyword 2.8 Accidents, Malfunctions and Unplanned Events
# 25
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W5.pdf for keyword 3 Consultation
# 25
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W5.pdf for keyword 3.1 Approach
# 25
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W5.pdf for keyword 3.2 Regulatory Consultation
# 25
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W5.pdf for keyword 3.3 Communities and Landowners Consultation
# 25
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W5.pdf for keyword 3.4 Aboriginal Engagement
# 25
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W5.pdf for keyword 3.5 Summary of Issues and Concerns
# 25
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W5.pdf for keyword 99 Appendix
# 26
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W6.pdf for keyword 1 Introduction
# 26
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W6.pdf for keyword 1.1 Purpose of the Environmental and Socio-Economic Assessment Report
# 26
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W6.pdf for keyword 1.2 Project Overview
# 26
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W6.pdf for keyword 1.3 Proponents
# 26
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W6.pdf for keyword 1.4 Project Components
# 26
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W6.pdf for keyword 1.5 Regulatory Context
# 26
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W6.pdf for keyword 1.6 Table of Concordance
# 26
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W6.pdf for keyword 1.7 Organization of the Environmental and Socio-economic Assessment Report
# 26
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W6.pdf for keyword 2 Project Description
# 26
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W6.pdf for keyword 2.1 Project Purpose and Need
# 26
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W6.pdf for keyword 2.2 Alternatives to the Project
# 26
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W6.pdf for keyword 2.3 Alternative Means
# 26
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W6.pdf for keyword 2.4 Project Components
# 26
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W6.pdf for keyword 2.5 Facilities
# 26
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W6.pdf for keyword 2.6 Operations and Maintenance
# 26
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W6.pdf for keyword 2.7 Decomissioning and Abandonment
# 26
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W6.pdf for keyword 2.8 Accidents, Malfunctions and Unplanned Events
# 26
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W6.pdf for keyword 3 Consultation
# 26
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W6.pdf for keyword 3.1 Approach
# 26
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W6.pdf for keyword 3.2 Regulatory Consultation
# 26
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W6.pdf for keyword 3.3 Communities and Landowners Consultation
# 26
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W6.pdf for keyword 3.4 Aboriginal Engagement
# 26
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W6.pdf for keyword 3.5 Summary of Issues and Concerns
# 26
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W6.pdf for keyword 99 Appendix
# 27
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W7.pdf for keyword 1 Introduction
# 27
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W7.pdf for keyword 1.1 Purpose of the Environmental and Socio-Economic Assessment Report
# 27
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W7.pdf for keyword 1.2 Project Overview
# 27
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W7.pdf for keyword 1.3 Proponents
# 27
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W7.pdf for keyword 1.4 Project Components
# 27
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W7.pdf for keyword 1.5 Regulatory Context
# 27
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W7.pdf for keyword 1.6 Table of Concordance
# 27
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W7.pdf for keyword 1.7 Organization of the Environmental and Socio-economic Assessment Report
# 27
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W7.pdf for keyword 2 Project Description
# 27
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W7.pdf for keyword 2.1 Project Purpose and Need
# 27
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W7.pdf for keyword 2.2 Alternatives to the Project
# 27
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W7.pdf for keyword 2.3 Alternative Means
# 27
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W7.pdf for keyword 2.4 Project Components
# 27
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W7.pdf for keyword 2.5 Facilities
# 27
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W7.pdf for keyword 2.6 Operations and Maintenance
# 27
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W7.pdf for keyword 2.7 Decomissioning and Abandonment
# 27
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W7.pdf for keyword 2.8 Accidents, Malfunctions and Unplanned Events
# 27
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W7.pdf for keyword 3 Consultation
# 27
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W7.pdf for keyword 3.1 Approach
# 27
# search started for file F:/Environmental Baseline Data/Version 3/Data/PDF/A1I9W7.pdf for keyword 3.2 Regulatory Consultation

# %%
len(PDF_Found)
len(PDF_names)
len(Chapter_numbers)

# %%
allChaptersDF.head(25)
len(allChaptersDF)
allChaptersDF.to_csv("F:/Environmental Baseline Data/Version 3/Indices/Index 4 all chunks- Chapters by TOC HTML.csv")

# %% [markdown]
# ### Adding Outlines

# %% [markdown]
# For some of the chunks that do not have TOC present in the HTML files might still have outlinmes present.

# %% [markdown]
# # Rough Work

# %%
def find_page_no(look_file_path, keyword):
    """ Given the Keyword and the PDF file, this function returs an array of 
    the page numbers on which the keyword was found"""
    object = p2.PdfFileReader(look_file_path)
    # get number of pages
    NumPages = object.getNumPages() 
    
    # chapter_key_index is set as 1 because we dont want to search for"0 Before First Chapter"
    # the array chapter_key_pages has first element 0 for the same reason
    chapter_key_index = 1
    chapter_key_page_Nos = [0]
    Flag_TOC_over = 0
    
    page_found = [-999]
    atleast_found_once = 0
    # extract text and do the search
    for i in range(0, NumPages):
        PageObj = object.getPage(i)
        #print("this is page " + str(i)) 
        try:
            Text = PageObj.extractText()
        except:
            Text = "Text could not be extracted"
        Text = Text.lower()
        Text = Text.replace("\n", "")
        # Text = Text
        # print (Text)
            
        #ResSearch = re.search(chapter_keys[chapter_key_index], Text)
        key = keyword.lower()
        if (key in Text):
            page_found.append(i)
            atleast_found_once = 1
            
    if atleast_found_once == 1:
        page_found = page_found[1:]
    return(page_found)

# %%
array = [1,2,3]
array = array[1:]
array
# Out:
# [2, 3]

# %%
# I dont think I needed this function 
def count_occorances(lst, x):
    count = 0
    for ele in lst:
        if ele == x:
            count = count + 1
    return count

# %%
df_outlines[["file_names"]].head(5)
# Out:
#    file_names
# 0  A0H8C0.pdf
# 1  A0H8C1.pdf
# 2  A0H8C2.pdf
# 3  A0H8C3.pdf
# 4  A0U3G1.pdf

# %%
len(df_outlines)
# Out:
# 1328

# %%
df_outlines[:1]
# Out:
#    file_nos  file_names                                         file_paths  \
# 0         1  A0H8C0.pdf  F:/Environmental Baseline Data/Version 3/Data/...
#
#    int_postals  outline_present TOC_present  consecutive_postals  chunk_nos
# 0        20300                1           1                    0          1

# %%
df_outlines[:1][["file_names"]]
# Out:
#    file_names
# 0  A0H8C0.pdf

# %%
df_outlines[:1][["outline_present"]]
(df_outlines[:1].values([outline_present]))
# Out:
#    outline_present
# 0                1
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-145-ab9a95bc71f8> in <module>
#       1 df_outlines[:1][["outline_present"]]
# ----> 2 (df_outlines[:1].values([outline_present]))
#
# TypeError: 'numpy.ndarray' object is not callable

# %%
df_outlines.iloc[0]['outline_present']
df_outlines.iloc[0]['outline_present'] == 1
# Out:
# 1
# True

# %%
current_df_outlines = df_outlines[df_outlines.chunk_nos == 3]
type(current_df_outlines.file_paths)
chunk_file_paths = current_df_outlines.file_paths
chunk_size = len(chunk_file_paths)
chunk_size
len(current_df_outlines.file_paths)
# Out:
# pandas.core.series.Series
# 2
# 2

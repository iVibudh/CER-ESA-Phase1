# %% [markdown]
# # Extracting Outlines from PDFs

# %% [markdown]
# The objective of this piece of code is to go through all the PDFs and detect if there are outlines present. The output of this code is the following: <br>
#
# 1. Outline_Present.csv - This has the list of the PDF files and then there is an indicator is the outline i spresent or not. <br>
#
# 2. Index 4 - Chapters.csv - This table has a detailed list of all the chapters present in all the PDF files present.

# %%
import PyPDF2 as p2
from pdfminer.pdfparser import PDFParser
from pdfminer.pdfdocument import PDFDocument
import pandas as pd
import os
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
#define the paths of the PDF scrapped 

path = 'F:/Environmental Baseline Data/Version 3/Data/PDF'
pdfs = os.listdir(path)
pdf_paths = [str(path) + '/' + str(x) for x in pdfs]
len(pdf_paths)
# Out:
# 1329

# %% [markdown]
# ## Extract Outlines for all the PDFs

# %%
# Functtion that runs recursively to extract the outlines of the PDF files
def nested_is_instance_check(s, level, file_name, file_names_ch, chapters, levels, pages):
    level +=1
    if isinstance(s, (int, list, float, complex)):
        for x in s:
            nested_is_instance_check(x, level, file_name, file_names_ch, chapters, levels, pages)
    else:
        chapters.extend([s.title])
        levels.extend([level])
        #it was observed that for a lot of PDF files we could not find the page number 
        # Hence, -999 is the error code added for those cases 
        try:
            pages.extend([pdfread.getDestinationPageNumber(s)])
        except: 
            pages.extend([-999])
        file_names_ch.append([file_name])

# %%
# Varibles for file outline_present.csv
file_names = []
outline_present = []

# Variables for Index 4 - Chapters.csv
file_names_ch = []
chapters = []
levels = []
pages = []


#pdf_paths = pdf_paths[0:10]

for pdf_path in pdf_paths:
    file_name = str(pdf_path.split('/')[-1])
    file_names.append(file_name)
    try:
        pdfread = p2.PdfFileReader(pdf_path)
        s = pdfread.outlines
        len_s = len(s)
    except:
        outline_present.append("Error in reading the outline")
        
    if len_s > 0:
        level = 0
        outline_present.append(1)
        nested_is_instance_check(s, level, file_name, file_names_ch, chapters, levels, pages)
    elif len_s == 0:
        outline_present.append(0)
    
    # Error Code for s (=pdfraed.outlines) is -999
    # the negative number allows exclusivity from the if and the elif conditions above
    len_s = -999
# Out:
# PdfReadWarning: Xref table not zero-indexed. ID numbers for objects will be corrected. [pdf.py:1736]

# %% [markdown]
# #### Saving the file outline_present.csv

# %%
len(file_names)
len(pdf_paths)
len(outline_present)
# Out:
# 1329
# 1329
# 1329

# %%
df_outlines = pd.DataFrame({'file_names': file_names, 'pdf_paths' : pdf_paths, 'outline_present' : outline_present})
df_outlines.head(5)
df_outlines.to_csv("F:/Environmental Baseline Data/Version 3/Indices/Outline_Present.csv")
# Out:
#    file_names                                          pdf_paths  \
# 0  A0H8C0.pdf  F:/Environmental Baseline Data/Version 3/Data/...
# 1  A0H8C1.pdf  F:/Environmental Baseline Data/Version 3/Data/...
# 2  A0H8C2.pdf  F:/Environmental Baseline Data/Version 3/Data/...
# 3  A0H8C3.pdf  F:/Environmental Baseline Data/Version 3/Data/...
# 4  A0U3G1.pdf  F:/Environmental Baseline Data/Version 3/Data/...
#
#   outline_present
# 0               1
# 1               1
# 2               0
# 3               0
# 4               0

# %% [markdown]
# #### Saving the file Index 4 - Chapters.csv

# %%
len(file_names_ch)
len(chapters)
len(pages)
len(levels)
# Out:
# 19439
# 19439
# 19439
# 19439

# %%
df_chapters = pd.DataFrame({'file_names': file_names_ch, 'chapters': chapters, 'pages' : pages, 'levels' : levels})
df_chapters.head(5)

df_chapters.to_csv("F:/Environmental Baseline Data/Version 3/Indices/Index 4 (Outlines) - Chapters and everything else.csv")


##########################################################################################
########## We might need to think of a better way to extract important chapters ##########
##########  df.chapters.levels < 5, is not teh best way ##################################
##########################################################################################
df_chapters = df_chapters[df_chapters.chapters is not None  and df_chapters.levels < 5]
df_chapters.head(5)
df_chapters.to_csv("F:/Environmental Baseline Data/Version 3/Indices/Index 4 (Outlines)- Chapters.csv")
# Out:
#      file_names                                           chapters  pages  \
# 0  [A0H8C0.pdf]  Environmental Impact Assessment and Mitigation...     24
# 1  [A0H8C0.pdf]                                       Introduction     24
# 2  [A0H8C0.pdf]                                 Project Background     24
# 3  [A0H8C0.pdf]                                 Regulatory Setting     24
# 4  [A0H8C0.pdf]                                                        -1
#
#    levels
# 0       2
# 1       3
# 2       4
# 3       4
# 4       5
#      file_names                                           chapters  pages  \
# 0  [A0H8C0.pdf]  Environmental Impact Assessment and Mitigation...     24
# 1  [A0H8C0.pdf]                                       Introduction     24
# 2  [A0H8C0.pdf]                                 Project Background     24
# 3  [A0H8C0.pdf]                                 Regulatory Setting     24
# 9  [A0H8C0.pdf]                  Scope of Environmental Assessment     26
#
#    levels
# 0       2
# 1       3
# 2       4
# 3       4
# 9       4
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-109-caab4090eff5> in <module>
#      11 df_chapters = df_chapters[df_chapters.chapters is not None  and df_chapters.levels < 5]
#      12 df_chapters.head(5)
# ---> 13 df_chapters.to_csv("F:/Environmental Baseline Data/Version 3/Indices/Index 4 (Outlines)- Chapters.csv")
#      14
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal)
#    3226             decimal=decimal,
#    3227         )
# -> 3228         formatter.save()
#    3229
#    3230         if path_or_buf is None:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     181                 self.mode,
#     182                 encoding=self.encoding,
# --> 183                 compression=self.compression,
#     184             )
#     185             close = True
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\common.py in _get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     397         if encoding:
#     398             # Encoding
# --> 399             f = open(path_or_buf, mode, encoding=encoding, newline="")
#     400         elif is_text:
#     401             # No explicit encoding
#
# PermissionError: [Errno 13] Permission denied: 'F:/Environmental Baseline Data/Version 3/Indices/Index 4 (Outlines)- Chapters.csv'

# %% [markdown]
# ## Is Table of contents Present?

# %%
txt_path = "F:/Environmental Baseline Data/Version 3/Data/Text/"
TOC_present = []
txt_file_needed = []
for file_name in file_names:
    # additional check to get rid of the string "Thumb"
    if 'Thum' not in file_name:  
        file_name_no_ext = file_name[:-4]
        
        try:
            file_handle = open(txt_path + file_name_no_ext +'.txt',"r", encoding="utf8")
            if file_handle.mode == 'r':
                contents = file_handle.read()
                contents = contents.upper()
                if 'TABLE OF CONTENTS' in contents:
                    TOC_present.append('TOC Present')
                else:
                    TOC_present.append('TOC Not Present')
            else:
                TOC_present.append('Error')
                
        except:
            print("This file was not present as text {}".format(file_name_no_ext))
            txt_file_needed.append(file_name_no_ext)
            TOC_present.append("Text file not present ")
            
    else:
        TOC_present.append("Thumb File")
# Out:
# This file was not present as text A5A8L7
# This file was not present as text A5A8L8
# This file was not present as text A5A8L9
# This file was not present as text A5A8Q0
# This file was not present as text A5A8Q1
# This file was not present as text A5A8Q2
# This file was not present as text A5A8Q3
# This file was not present as text A5A8Q4
# This file was not present as text A5A8Q5
# This file was not present as text A5A8Q6
# This file was not present as text A5A8Q7
# This file was not present as text A5A8R1
# This file was not present as text A5A8R2
# This file was not present as text A5A8R3
# This file was not present as text A5A8R4
# This file was not present as text A5A8R5
# This file was not present as text A5A8R6
# This file was not present as text A5A8R7
# This file was not present as text A5A8R8
# This file was not present as text A5A8R9
# This file was not present as text A5A8S0
# This file was not present as text A5A8S1
# This file was not present as text A5A8S2
# This file was not present as text A5A8S3
# This file was not present as text A5A8S4
# This file was not present as text A5A8S5
# This file was not present as text A5A8S6
# This file was not present as text A5A8S7
# This file was not present as text A5A8S8
# This file was not present as text A5A8S9
# This file was not present as text A5A8T0
# This file was not present as text A5A8T1
# This file was not present as text A5A8T2
# This file was not present as text A5A8T3
# This file was not present as text A5A8T4
# This file was not present as text A5A8T5
# This file was not present as text A5A8T6
# This file was not present as text A5A8T7
# This file was not present as text A5A8T8
# This file was not present as text A5A8T9
# This file was not present as text A5A8U0
# This file was not present as text A5A8U1
# This file was not present as text A5A8U2
# This file was not present as text A5A8U3
# This file was not present as text A5A8U4
# This file was not present as text A5A8U5
# This file was not present as text A5A8U6
# This file was not present as text A5A8U7
# This file was not present as text A5A8U8
# This file was not present as text A5A8U9
# This file was not present as text A5A8V0
# This file was not present as text A5A8V1
# This file was not present as text A5A8V2
# This file was not present as text A5A8V3
# This file was not present as text A5A8V4
# This file was not present as text A5A8V5
# This file was not present as text A5A8V6
# This file was not present as text A5A8V7
# This file was not present as text A5A8V8
# This file was not present as text A5A8V9
# This file was not present as text A5A8W0
# This file was not present as text A5A8W3
# This file was not present as text A5A8W4
# This file was not present as text A5A8W5
# This file was not present as text A5A8W6
# This file was not present as text A5A8W7
# This file was not present as text A5A8W8
# This file was not present as text A5A8W9
# This file was not present as text A5A8X0
# This file was not present as text A5A8X1
# This file was not present as text A5A8X2
# This file was not present as text A5A8X3
# This file was not present as text A5A8X4
# This file was not present as text A5A8X5
# This file was not present as text A5A8X6
# This file was not present as text A5A8X7
# This file was not present as text A5A8X8
# This file was not present as text A5A8X9
# This file was not present as text A5A8Y0
# This file was not present as text A5A8Y1
# This file was not present as text A5A8Y2
# This file was not present as text A5A8Y3
# This file was not present as text A5A8Y4
# This file was not present as text A5A8Y5
# This file was not present as text A5A8Y6
# This file was not present as text A5A8Y7
# This file was not present as text A5A8Y8
# This file was not present as text A5A8Y9
# This file was not present as text A5A8Z0
# This file was not present as text A5A8Z1
# This file was not present as text A5A8Z2
# This file was not present as text A5A8Z3
# This file was not present as text A5A8Z4
# This file was not present as text A5A8Z5
# This file was not present as text A5A8Z6
# This file was not present as text A5A8Z7
# This file was not present as text A5A8Z8
# This file was not present as text A5A8Z9
# This file was not present as text A5A9A1
# This file was not present as text A5A9A2
# This file was not present as text A5A9A3
# This file was not present as text A5A9A4
# This file was not present as text A5A9A5
# This file was not present as text A5A9C7
# This file was not present as text A5A9C8
# This file was not present as text A5A9C9
# This file was not present as text A5A9D0
# This file was not present as text A5A9D1
# This file was not present as text A5A9D2
# This file was not present as text A5A9D3
# This file was not present as text A5A9D4
# This file was not present as text A5A9D5
# This file was not present as text A5A9D6
# This file was not present as text A5A9D7
# This file was not present as text A5A9D8
# This file was not present as text A5A9D9
# This file was not present as text A5A9E0
# This file was not present as text A5A9E1
# This file was not present as text A5A9E2
# This file was not present as text A5A9E3
# This file was not present as text A5A9E4
# This file was not present as text A5A9E5
# This file was not present as text A5A9E6
# This file was not present as text A5A9E7
# This file was not present as text A5A9E8
# This file was not present as text A5A9E9
# This file was not present as text A5A9F0
# This file was not present as text A5A9F1
# This file was not present as text A5A9F2
# This file was not present as text A5A9F3
# This file was not present as text A5A9F4
# This file was not present as text A5A9F5
# This file was not present as text A5A9F6
# This file was not present as text A5A9F7
# This file was not present as text A5A9F8
# This file was not present as text A5A9F9
# This file was not present as text A5A9G0
# This file was not present as text A5A9G1
# This file was not present as text A5A9G2
# This file was not present as text A5A9G3
# This file was not present as text A5A9G4
# This file was not present as text A5A9G5
# This file was not present as text A5A9G6
# This file was not present as text A5A9G7
# This file was not present as text A5A9G8
# This file was not present as text A5A9R4
# This file was not present as text A5A9R5
# This file was not present as text A5A9R6
# This file was not present as text A5A9R7
# This file was not present as text A5A9R8
# This file was not present as text A5A9R9
# This file was not present as text A5A9S4
# This file was not present as text A5A9S5
# This file was not present as text A5A9S6
# This file was not present as text A5A9S7
# This file was not present as text A5A9S8
# This file was not present as text A5A9S9
# This file was not present as text A5A9T0
# This file was not present as text A5A9T1
# This file was not present as text A5A9T2
# This file was not present as text A5A9T3
# This file was not present as text A5A9T4
# This file was not present as text A5A9T5
# This file was not present as text A5A9T6
# This file was not present as text A5A9T7
# This file was not present as text A5A9T8
# This file was not present as text A5A9T9
# This file was not present as text A5A9U0
# This file was not present as text A5A9U1
# This file was not present as text A5A9U2
# This file was not present as text A5A9U3
# This file was not present as text A5A9U4
# This file was not present as text A5A9U5
# This file was not present as text A5A9U6
# This file was not present as text A5A9U8
# This file was not present as text A5G2W9
# This file was not present as text A5G2X0
# This file was not present as text A5G2X1
# This file was not present as text A5G2X2
# This file was not present as text A5G2X3
# This file was not present as text A5G2X4
# This file was not present as text A5G2X5
# This file was not present as text A5G2X6
# This file was not present as text A5G2X7
# This file was not present as text A5G2X8
# This file was not present as text A5G2X9
# This file was not present as text A5G2Y0
# This file was not present as text A5G2Y1
# This file was not present as text A5G2Y3
# This file was not present as text A5V8D5
# This file was not present as text A5V8D6
# This file was not present as text A5V8D7
# This file was not present as text A5V8D8
# This file was not present as text A5V8D9
# This file was not present as text A5V8E0
# This file was not present as text A5V8E1
# This file was not present as text A5V8E2
# This file was not present as text A5V8E3
# This file was not present as text A5V8E4
# This file was not present as text A5V8E5
# This file was not present as text A5V8E6
# This file was not present as text A5V8E7
# This file was not present as text A5V8E8
# This file was not present as text A5V8E9
# This file was not present as text A5V8F0
# This file was not present as text A5V8F1
# This file was not present as text A5V8F2
# This file was not present as text A5V8F3
# This file was not present as text A5V8F4
# This file was not present as text A5V8F5
# This file was not present as text A5V8F6
# This file was not present as text A5V8F7
# This file was not present as text A5V8F8
# This file was not present as text A5V8F9
# This file was not present as text A5V8G0
# This file was not present as text A5V8G1
# This file was not present as text A5V8G2
# This file was not present as text A6A2C8
# This file was not present as text A6A2C9
# This file was not present as text A6A2D0
# This file was not present as text A6A2D1
# This file was not present as text A6A2D2
# This file was not present as text A6A2D3
# This file was not present as text A6A2D4
# This file was not present as text A6A2D5
# This file was not present as text A6A2D6
# This file was not present as text A6C8K0
# This file was not present as text A6F4Q3
# This file was not present as text A6F4Q4
# This file was not present as text A6F4Q5
# This file was not present as text A6F4Q6
# This file was not present as text A6F4Q7
# This file was not present as text A6F4Q8
# This file was not present as text A6F4Q9
# This file was not present as text A6F4R0
# This file was not present as text A6F4R1
# This file was not present as text A6F4R2
# This file was not present as text A6I8E1
# This file was not present as text A6T2G2
# This file was not present as text A6T2G3
# This file was not present as text A6T2G4
# This file was not present as text A6T2G5
# This file was not present as text A6T2G6
# This file was not present as text A6T2G7
# This file was not present as text A6T2G8
# This file was not present as text A6T2G9
# This file was not present as text A6T2H0
# This file was not present as text A6T2H1
# This file was not present as text A6T2H2
# This file was not present as text A6T2H3
# This file was not present as text A6T2H4
# This file was not present as text A6T2H5
# This file was not present as text A6T2H6
# This file was not present as text A6T2V6
# This file was not present as text A6T2V7
# This file was not present as text A6T2V8
# This file was not present as text A6T2V9
# This file was not present as text A6T2W2
# This file was not present as text A6T2W3
# This file was not present as text A6T2W4
# This file was not present as text A6T2W5
# This file was not present as text A6T2W6

# %%
len(txt_file_needed)
# Out:
# 262

# %%
len(TOC_present)
len(file_names)
# Out:
# 1329
# 1329

# %%
df_outlines['TOC_present'] = TOC_present
df_outlines.head(5)
df_outlines.to_csv("F:/Environmental Baseline Data/Version 3/Indices/Outline_Present.csv")
# Out:
#    file_names                                          pdf_paths  \
# 0  A0H8C0.pdf  F:/Environmental Baseline Data/Version 3/Data/...
# 1  A0H8C1.pdf  F:/Environmental Baseline Data/Version 3/Data/...
# 2  A0H8C2.pdf  F:/Environmental Baseline Data/Version 3/Data/...
# 3  A0H8C3.pdf  F:/Environmental Baseline Data/Version 3/Data/...
# 4  A0U3G1.pdf  F:/Environmental Baseline Data/Version 3/Data/...
#
#   outline_present      TOC_present
# 0               1      TOC Present
# 1               1  TOC Not Present
# 2               0  TOC Not Present
# 3               0  TOC Not Present
# 4               0      TOC Present

# %% [markdown]
# # Postal to Int Functions

# %%
def postal_to_int(Postal):
    multiplier = 1
    odd = 1
    Postal_Int_Word = 0
    Error_Message = "Invalid Postal Code"
    
    # Reversing the string 
    Postal = Postal[::-1] 
    
    # Chcek for the length of the Postal Code
    if not(len(Postal)==6):
        return(Error_Message)
    
    for letter in list(str.strip(Postal)):
        if odd%2 == 1:
            # Check if it is an interger or not   
            # If this is not an integer then exit
            if not (str.isnumeric(letter)):
                return(Error_Message)
            
            Postal_Int_Letter = multiplier * int(letter)
            Postal_Int_Word = Postal_Int_Word + Postal_Int_Letter
            
            odd = odd + 1
            multiplier = multiplier * 10
            # print(letter, Postal_Int_Letter)
            # print(Postal_Int_Word)
        else:
            # Check if it is a character or not
            # If this is not a character then exit
            if not (str.isalpha(letter)):
                return(Error_Message)
            
            # ord('A') = 65
            Postal_Int_Letter = multiplier * (ord(letter) - 65)
            Postal_Int_Word = Postal_Int_Word + Postal_Int_Letter
            
            odd = odd + 1
            multiplier = multiplier * 26
            # print(letter, Postal_Int_Letter)
            # print(Postal_Int_Word)
            
    return Postal_Int_Word

# %%
# never used integer to Postal but I guess it would be useful 
# Also useful in validating if Postal to Int Function works 

def int_to_postal(Postal_Int_Word):
    Postal_Int_Word_Rem = Postal_Int_Word
    Postal = ""
    odd = 0
    Error_Message = "Invalid Postal Code"
    
    # Reversing the string 
    Postal = Postal[::-1] 
 
    while odd < 6:
        if odd%2 == 0:
            Postal_Int_Letter = Postal_Int_Word_Rem % 10
            Postal = Postal + str(Postal_Int_Letter)
            Postal_Int_Word_Rem = int(Postal_Int_Word_Rem/10)
            odd = odd + 1

        else:
            Postal_Int_Letter = (Postal_Int_Word_Rem % 26) +65
            Postal = Postal + chr(Postal_Int_Letter)
            Postal_Int_Word_Rem = int(Postal_Int_Word_Rem/26)
            odd = odd + 1
            
    # Accounts for 7 digit Postal Codes
    if Postal_Int_Word_Rem > 0:
        return(Error_Message)
        
    return Postal[::-1]

# %%
int_postals = []
for file_name in file_names:
    postal = file_name[:-4]
    int_postal = postal_to_int(postal)
    int_postals.append(int_postal)
    
len(int_postals)
len(file_names)
# Out:
# 1329
# 1329

# %%
df_outlines['Int_Postal_Codes'] = int_postals
df_outlines.head(5)
df_outlines.to_csv("F:/Environmental Baseline Data/Version 3/Indices/Outline_Present.csv")
# Out:
#    file_names                                          pdf_paths  \
# 0  A0H8C0.pdf  F:/Environmental Baseline Data/Version 3/Data/...
# 1  A0H8C1.pdf  F:/Environmental Baseline Data/Version 3/Data/...
# 2  A0H8C2.pdf  F:/Environmental Baseline Data/Version 3/Data/...
# 3  A0H8C3.pdf  F:/Environmental Baseline Data/Version 3/Data/...
# 4  A0U3G1.pdf  F:/Environmental Baseline Data/Version 3/Data/...
#
#   outline_present      TOC_present Int_Postal_Codes
# 0               1      TOC Present            20300
# 1               1  TOC Not Present            20301
# 2               0  TOC Not Present            20302
# 3               0  TOC Not Present            20303
# 4               0      TOC Present            52841

# %%
chunk_nos = []
chunk = 0
last_postal = int_postals[0]

for int_postal in int_postals:
    if int_postal == last_postal + 1:
        chunk_nos.append(chunk)
    else:
        chunk = chunk +1
        chunk_nos.append(chunk)
    last_postal = int_postal

# %%
df_outlines['chunk_nos'] = chunk_nos
df_outlines.head(5)
df_outlines.to_csv("F:/Environmental Baseline Data/Version 3/Indices/Outline_Present.csv")
# Out:
#    file_names                                          pdf_paths  \
# 0  A0H8C0.pdf  F:/Environmental Baseline Data/Version 3/Data/...
# 1  A0H8C1.pdf  F:/Environmental Baseline Data/Version 3/Data/...
# 2  A0H8C2.pdf  F:/Environmental Baseline Data/Version 3/Data/...
# 3  A0H8C3.pdf  F:/Environmental Baseline Data/Version 3/Data/...
# 4  A0U3G1.pdf  F:/Environmental Baseline Data/Version 3/Data/...
#
#   outline_present      TOC_present Int_Postal_Codes  chunk_nos
# 0               1      TOC Present            20300          1
# 1               1  TOC Not Present            20301          1
# 2               0  TOC Not Present            20302          1
# 3               0  TOC Not Present            20303          1
# 4               0      TOC Present            52841          2

# %%
for current_chunk in range(0,chunk):
    current_df = df_outlines[df_outlines.chunk_nos == current_chunk]
    if current_chunk > 2:
        break
        
current_df
# Out:
#     file_names                                          pdf_paths  \
# 6   A0Y1T7.pdf  F:/Environmental Baseline Data/Version 3/Data/...
# 7   A0Y1T8.pdf  F:/Environmental Baseline Data/Version 3/Data/...
# 8   A0Y1T9.pdf  F:/Environmental Baseline Data/Version 3/Data/...
# 9   A0Y1U0.pdf  F:/Environmental Baseline Data/Version 3/Data/...
# 10  A0Y1U1.pdf  F:/Environmental Baseline Data/Version 3/Data/...
# 11  A0Y1U2.pdf  F:/Environmental Baseline Data/Version 3/Data/...
# 12  A0Y1U3.pdf  F:/Environmental Baseline Data/Version 3/Data/...
# 13  A0Y1U4.pdf  F:/Environmental Baseline Data/Version 3/Data/...
# 14  A0Y1U5.pdf  F:/Environmental Baseline Data/Version 3/Data/...
# 15  A0Y1U6.pdf  F:/Environmental Baseline Data/Version 3/Data/...
# 16  A0Y1U7.pdf  F:/Environmental Baseline Data/Version 3/Data/...
# 17  A0Y1U8.pdf  F:/Environmental Baseline Data/Version 3/Data/...
# 18  A0Y1U9.pdf  F:/Environmental Baseline Data/Version 3/Data/...
# 19  A0Y1V0.pdf  F:/Environmental Baseline Data/Version 3/Data/...
# 20  A0Y1V1.pdf  F:/Environmental Baseline Data/Version 3/Data/...
# 21  A0Y1V2.pdf  F:/Environmental Baseline Data/Version 3/Data/...
# 22  A0Y1V3.pdf  F:/Environmental Baseline Data/Version 3/Data/...
# 23  A0Y1V4.pdf  F:/Environmental Baseline Data/Version 3/Data/...
# 24  A0Y1V5.pdf  F:/Environmental Baseline Data/Version 3/Data/...
# 25  A0Y1V6.pdf  F:/Environmental Baseline Data/Version 3/Data/...
# 26  A0Y1V7.pdf  F:/Environmental Baseline Data/Version 3/Data/...
# 27  A0Y1V8.pdf  F:/Environmental Baseline Data/Version 3/Data/...
# 28  A0Y1V9.pdf  F:/Environmental Baseline Data/Version 3/Data/...
# 29  A0Y1W0.pdf  F:/Environmental Baseline Data/Version 3/Data/...
# 30  A0Y1W1.pdf  F:/Environmental Baseline Data/Version 3/Data/...
#
#                  outline_present      TOC_present Int_Postal_Codes  chunk_nos
# 6                              1      TOC Present            62857          3
# 7                              1  TOC Not Present            62858          3
# 8                              1  TOC Not Present            62859          3
# 9                              1  TOC Not Present            62860          3
# 10  Error in reading the outline  TOC Not Present            62861          3
# 11  Error in reading the outline  TOC Not Present            62862          3
# 12  Error in reading the outline  TOC Not Present            62863          3
# 13  Error in reading the outline  TOC Not Present            62864          3
# 14                             0  TOC Not Present            62865          3
# 15                             0  TOC Not Present            62866          3
# 16                             0  TOC Not Present            62867          3
# 17                             1      TOC Present            62868          3
# 18                             1  TOC Not Present            62869          3
# 19                             1  TOC Not Present            62870          3
# 20                             1  TOC Not Present            62871          3
# 21                             1  TOC Not Present            62872          3
# 22                             0      TOC Present            62873          3
# 23                             0      TOC Present            62874          3
# 24                             1      TOC Present            62875          3
# 25                             1      TOC Present            62876          3
# 26                             1  TOC Not Present            62877          3
# 27                             0  TOC Not Present            62878          3
# 28                             1  TOC Not Present            62879          3
# 29                             1  TOC Not Present            62880          3
# 30                             1  TOC Not Present            62881          3

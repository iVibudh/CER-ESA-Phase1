# %% [markdown]
# # Extracting Metadata from chapters

# %%
import re
import numpy as np
import pandas as pd
from pprint import pprint

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
allChaptersDF = pd.read_csv(
    "F:\Environmental Baseline Data\Version 3\Indices\Index 4 8 chunks- Chapters by TOC HTML.csv")
 
len(allChaptersDF)
allChaptersDF[20:30].head(5)
# Out:
# 135
#     Unnamed: 0   PDF_names                                      PDF_locations  \
# 20           4  A0U3G1.pdf  F:/Environmental Baseline Data/Version 3/Data/...
# 21           5  A0U3G1.pdf  F:/Environmental Baseline Data/Version 3/Data/...
# 22           6  A0U3G1.pdf  F:/Environmental Baseline Data/Version 3/Data/...
# 23           7  A0U3G1.pdf  F:/Environmental Baseline Data/Version 3/Data/...
# 24           8  A0U3G1.pdf  F:/Environmental Baseline Data/Version 3/Data/...
#
#     Chapter_numbers                     Chapter_texts  \
# 20              1.3  Purpose and Need for the Project
# 21              1.4              Regulatory Framework
# 22              1.5        Organization of the Report
# 23              2.0               PROJECT DESCRIPTION
# 24              2.1   Project Definition and Location
#
#                             Chapter_keys       PDF_Found  Page_Found
# 20  1.3 Purpose and Need for the Project  ['A0U3G1.pdf']  [[14, 29]]
# 21              1.4 Regulatory Framework  ['A0U3G1.pdf']  [[14, 29]]
# 22        1.5 Organization of the Report  ['A0U3G1.pdf']  [[14, 31]]
# 23               2.0 PROJECT DESCRIPTION  ['A0U3G1.pdf']  [[14, 33]]
# 24   2.1 Project Definition and Location  ['A0U3G1.pdf']  [[14, 33]]

# %%
PDF_locations = set(allChaptersDF["PDF_locations"])
len(PDF_locations)
allChaptersDF.iloc[3]['PDF_Found']
# Out:
# 6
# "['A0H8C0.pdf']"

# %%
def get_last_PDF(pdf_list):
    pdf_list = pdf_list.replace("[","")
    pdf_list = pdf_list.replace("]","")
    pdf_list = pdf_list.replace("'","")
    pdf_list = pdf_list.replace('"','')
    pdf_list = pdf_list.split(",")
    a = pdf_list[len(pdf_list) - 1]
    a.strip()
    return(a)


def get_last_page(page_list_str):
    if page_list_str == '[]':
        return(0)
    
    page_lists = page_list_str.split("]],[[")
    page_list_2D = []
    
    for page_list in page_lists:
        page_list_2D.append(page_list.split(","))
        
    llist = []
    for i in range(len(page_list_2D)):
        l = []
        for j in range(len(page_list_2D[i])):
            a = page_list_2D[i][j]
            a = a.replace("[","")
            a = a.replace("]","")
            a = a.replace("'","")
            a = a.replace('"','')
            a.strip
            l.append(a)
        llist.append(l)
    
    result = llist[len(llist) - 1][len(llist[len(llist)-1])-1]
                                
    return(int(result))

# %%
Key_Found = []
PDF_Found_Last = []
Page_Found_Last = []

for i in range(len(allChaptersDF)):
    PDF_Found_Last_ele = get_last_PDF(allChaptersDF.iloc[i]['PDF_Found'])
    PDF_Found_Last.append(PDF_Found_Last_ele)
    Page_Found_Last_ele = get_last_page(allChaptersDF.iloc[i]['Page_Found'])
    Page_Found_Last.append(Page_Found_Last_ele)
    Key_Found.append(PDF_Found_Last_ele + ' - ' + str(Page_Found_Last_ele))
    
#allChaptersDF['Key_Found'] = Key_Found
allChaptersDF['Page_Found_Last'] = Page_Found_Last
allChaptersDF['PDF_Found_Last'] = PDF_Found_Last
allChaptersDF
# Out:
#      Unnamed: 0   PDF_names  \
# 0             0  A0H8C0.pdf
# 1             1  A0H8C0.pdf
# 2             2  A0H8C0.pdf
# 3             3  A0H8C0.pdf
# 4             4  A0H8C0.pdf
# ..          ...         ...
# 130           9  A0Y1V5.pdf
# 131          10  A0Y1V5.pdf
# 132          11  A0Y1V5.pdf
# 133          12  A0Y1V5.pdf
# 134          13  A0Y1V5.pdf
#
#                                          PDF_locations  Chapter_numbers  \
# 0    F:/Environmental Baseline Data/Version 3/Data/...              0.0
# 1    F:/Environmental Baseline Data/Version 3/Data/...             13.0
# 2    F:/Environmental Baseline Data/Version 3/Data/...             13.1
# 3    F:/Environmental Baseline Data/Version 3/Data/...             13.2
# 4    F:/Environmental Baseline Data/Version 3/Data/...             13.3
# ..                                                 ...              ...
# 130  F:/Environmental Baseline Data/Version 3/Data/...              4.0
# 131  F:/Environmental Baseline Data/Version 3/Data/...              5.0
# 132  F:/Environmental Baseline Data/Version 3/Data/...              5.1
# 133  F:/Environmental Baseline Data/Version 3/Data/...              5.2
# 134  F:/Environmental Baseline Data/Version 3/Data/...             99.0
#
#                                          Chapter_texts  \
# 0                                 Before First Chapter
# 1    Environmental Impact Assessment and Mitigation...
# 2                                         Introduction
# 3                                  Project Description
# 4                                   Assessment Methods
# ..                                                 ...
# 130                             RECOMMENDED MITIGATION
# 131                                         REFERENCES
# 132                            Personal Communications
# 133                                   Literature Cited
# 134                                           Appendix
#
#                                           Chapter_keys       PDF_Found  \
# 0                               0 Before First Chapter            [-1]
# 1    13 Environmental Impact Assessment and Mitigat...  ['A0H8C0.pdf']
# 2                                    13.1 Introduction  ['A0H8C0.pdf']
# 3                             13.2 Project Description  ['A0H8C0.pdf']
# 4                              13.3 Assessment Methods  ['A0H8C0.pdf']
# ..                                                 ...             ...
# 130                         4.0 RECOMMENDED MITIGATION  ['A0Y1V5.pdf']
# 131                                     5.0 REFERENCES  ['A0Y1V5.pdf']
# 132                        5.1 Personal Communications  ['A0Y1V5.pdf']
# 133                               5.2 Literature Cited  ['A0Y1V5.pdf']
# 134                                        99 Appendix              []
#
#     Page_Found  Page_Found_Last PDF_Found_Last
# 0         [-1]               -1             -1
# 1    [[1, 24]]               24     A0H8C0.pdf
# 2    [[1, 24]]               24     A0H8C0.pdf
# 3    [[1, 27]]               27     A0H8C0.pdf
# 4    [[1, 36]]               36     A0H8C0.pdf
# ..         ...              ...            ...
# 130  [[2, 16]]               16     A0Y1V5.pdf
# 131  [[2, 21]]               21     A0Y1V5.pdf
# 132  [[2, 21]]               21     A0Y1V5.pdf
# 133  [[2, 21]]               21     A0Y1V5.pdf
# 134         []                0
#
# [135 rows x 10 columns]

# %% [markdown]
# ### Reading Chapter Text

# %%
def read_chapter_text(PDF_Path, 
                      i):
    try:
        End_File_Name = allChaptersDF.iloc[i+1]['PDF_Found']
        if allChaptersDF.iloc[i+1]['Chunk_Nos'] == allChaptersDF.iloc[i]['Chunk_Nos']:
            # End of chunk throw error
    except:
        End_File_Name = "End of PDF Chunk"
    
   


    PDF_Name = allChaptersDF.iloc[i+1]['PDF_Found']
    Chapter_Text = allChaptersDF.iloc[i]['Chapter_keys']
    while 1:
        print("Reading PDF {}".format(allChaptersDF.iloc[i+1]['PDF_Found']))
        object = p2.PdfFileReader(look_file_path)
        
        # get number of pages
        NumPages = object.getNumPages()
        
        for i in range(allChaptersDF.iloc[i+1]['Page_Found_Last'], 
                       End_Page):
            PageObj = object.getPage(i)
            #print("this is page " + str(i)) 
            try:
                Text = PageObj.extractText()
                Chapter.append(Text)
                
            except:
                Text = "Text could not be extracted"
                print(Text)
                    
        
            
    if atleast_found_once == 1:
        page_found = page_found[1:]
    return(page_found)

# %%
chapter_text = []
for i in range(len(allChaptersDF)):
    chapter_text.append(read_chapter_text(PDF_Path, i)

# %% [markdown]
# # Rough Work

# %%
try:
    5/0
except:
    print("Error Thrown")
# Out:
# Error Thrown

# %%
def fn_call(i):
    if i == 3:
        return(i+1)
    return i 
        

for i in range(0,5):
    i = fn_call(i)
    print(i)
# Out:
# 0
# 1
# 2
# 4
# 4
